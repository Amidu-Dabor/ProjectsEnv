# %% [markdown]
# # Polynomial Regression
# - #### To Predict the previous salary of a new Employee (recruit) and compare to the their expected salary

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_theme()

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv('Position_Salaries.csv')
df
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
X = df.iloc[:, 1:-1].values
y = df.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression Results

# %%
plt.scatter(X, y, color ='red')
plt.plot(X, lin_reg.predict(X), color = 'blue')
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Evaluating the Linear Regression model

# %%
# from sklearn.metrics import r2_score

# r2 = r2_score(y_true=y_train, y_pred=y_pred)
# n = X.shape[0]
# k = X.shape[1]
# adjusted_r2 = 1-(1-r2)*(n-1)/(n-k-1)
# print(f'R-squared: {r2:.3f}, Adjusted R-squared: {adjusted_r2:.3f}')
# Out:
# R-squared: -11589234493.972, Adjusted R-squared: -13037888805.843

# %% [markdown]
# ## Visualising the Polynomial Regression Results

# %%
plt.scatter(X, y, color ='red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression Results (for higher resolution and smoother curve)

# %%
X_grid = np.arange(min(X), max(X), step=0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color ='red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
# Out:
# /var/folders/x4/dd2xz8_d4fjbb7kzdq5sp8_40000gn/T/ipykernel_21133/4315354.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), step=0.1)

# %% [markdown]
# ## Evaluating the Polynomial Regression model

# %%
# from sklearn.metrics import r2_score

# r2 = r2_score(y_true=y_train, y_pred=y_pred)
# n = X.shape[0]
# k = X.shape[1]
# adjusted_r2 = 1-(1-r2)*(n-1)/(n-k-1)
# print(f'R-squared: {r2:.3f}, Adjusted R-squared: {adjusted_r2:.3f}')

# %% [markdown]
# ## Predicting a new result (the salary) with Linear Regression

# %%
# Using the linear features to make the prediction (for a specific position level)
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result (the salary) with Polynomial Regression

# %%
# Using the polynomial features to make the prediction
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265154])
