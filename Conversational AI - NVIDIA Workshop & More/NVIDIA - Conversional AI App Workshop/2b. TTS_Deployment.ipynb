# %% [markdown]
# <a href="https://www.nvidia.com/dli"> <img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/> </a>

# %% [markdown]
# # 7.0 TTS Pipeline Deployment with NVIDIA Riva
# ## (part of Lab 2)

# %% [markdown]
# In this notebook, we'll deploy TTS with  [NVIDIA Riva](https://developer.nvidia.com/riva). After the model is deployed in Riva, you can issue inference requests to the Riva server from a client.
#
# **[7.1 Launch Riva Server](#7.1-Launch-Riva-Server)<br>**
# &nbsp;&nbsp;&nbsp;&nbsp;[7.1.1 Riva Configuration](#7.1.1-Riva-Configuration)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[7.1.2 Exercise: Configure Riva for TTS](#7.1.2-Exercise:-Configure-Riva-for-TTS)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[7.1.3 Riva Start Services](#7.1.3-Riva-Start-Services)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[7.1.4 Riva Available Services Check](#7.1.4-Riva-Available-Services-Check)<br>
# **[7.2 Riva TTS Service Request](#7.2-Riva-TTS-Service-Request)<br>**
# &nbsp;&nbsp;&nbsp;&nbsp;[7.2.1 Python Client Demo](#7.2.1-Python-Client-Demo)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[7.2.2 Customizing TTS](#7.2.2-Customizing-TTS)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[7.2.3 Exercise: Customize Phonemes](#7.2.3-Exercise:-Customize-Phonemes)<br>
# **[7.3 Stop Riva Services](#7.3-Stop-Riva-Services)<br>**
# **[7.4 Shut Down the Kernel](#7.4-Shut-Down-the-Kernel)<br>**

# %% [markdown]
# ### Notebook Dependencies
# The steps in this notebook assume that you have:
#
# 1. **NGC Credentials**<br>Be sure you have added your NGC credential as described in the [NGC Setup notebook](003_Intro_NGC_Setup.ipynb)

# %% [markdown]
# ---
# # 7.1 Launch Riva Server
# We'll repeat the process of deployment with Riva that we used for ASR, but this time we will choose to deploy the TTS models instead.  Once again, we'll use the
# Riva Quick Start scripts downloaded from NGC.
#
# Set `RIVA_QS` to the `riva_quickstart` location.  We'll use a new location for the model repo to just contain the TTS models, as this will be a little faster to deploy.

# %%
# Set the Riva Quick Start directory
WORKSPACE='/dli_workspace'
RIVA_QS = WORKSPACE + "/riva_quickstart"
RIVA_MODEL_REPO = WORKSPACE + "/riva-tts-model-repo"
# !mkdir -p $RIVA_MODEL_REPO

# %%
# !ls $RIVA_QS
# Out:
# asr_lm_tools			  protos	 riva_start.sh
# config.sh			  riva_clean.sh  riva_start_client.sh
# nemo2riva-2.8.1-py3-none-any.whl  riva_init.sh	 riva_stop.sh

# %% [markdown]
# As with ASR, we can initialize the models using `riva_init.sh`, then start and stop the server with `riva_start.sh` and `riva_stop.sh`. We also need to set flags and values in `config.sh` to specify which services and models we want to initiate and start.

# %% [markdown]
# ## 7.1.1 Riva Configuration

# %% [markdown]
# Open [config.sh](dli_workspace/riva_quickstart/config.sh) and note the following important sections, which may still be set for ASR deployment.  You'll need to modify these sections.
#
# ##### Enable/Disable Riva Services
# For each service, a true value means that the server is enabled for that particular capability.  For example, if we just want to run an ASR server, we can set the `service_enabled_tts` parameter to be `true` and all other parameters `false`.  An enabled service also means that later in the config file, all NGC models listed in the section will be downloaded.
# ```yaml
# # Enable or Disable Riva Services
# service_enabled_asr=true
# service_enabled_nlp=true
# service_enabled_tts=true
# ```
#
# ##### Specify the Language
# You can specify the language code for the models that will be loaded.  The instructions and available language codes are included in the `config.sh` file:
# ```yaml
# # Language code to fetch models of a specify language
# # Currently only ASR supports languages other than English
# # Supported language codes: ar-AR, en-US, en-GB, de-DE, es-ES, es-US, fr-FR, hi-IN, it-IT, ja-JP, ru-RU, ko-KR, pt-BR, zh-CN
# # for any language other than English, set service_enabled_nlp and service_enabled_tts to False
# # for multiple languages enter space separated language codes.
# language_code=("en-US")
# ```
#
# ##### Set the Encryption Key
#    We want our encryption consistent for all of our projects, so we want this key to be the same as the one used to export our original model (and it already is!).  For the purposes of this class, this setting won't change.
# ```yaml
# # Specify the encryption key to use to deploy models
# MODEL_DEPLOY_KEY="tlt_encode"
# ```
#
# ##### Set the Model Location
# `riva_model_loc` should be the folder that contains both the `rmir` folder `models` folders.  This value will need to be changed to the actual absolute path for a given project.
# ```yaml
# # Custom models produced by NeMo or TLT and prepared using riva-build
# # may also be copied manually to this location $(riva_model_loc/rmir).
# #
# # Models ($riva_model_loc/models)
# # During the riva_init process, the RMIR files in $riva_model_loc/rmir
# # are inspected and optimized for deployment. The optimized versions are
# # stored in $riva_model_loc/models. The riva server exclusively uses these
# # optimized versions.
# riva_model_loc="/riva-model-repo"
# ```

# %% [markdown]
# ## 7.1.2 Exercise: Configure Riva for TTS
#
# Open [config.sh](dli_workspace/riva_quickstart/config.sh) and modify it to:
# * Deploy only the TTS service
# * Specify only English
# * Specify the `/dli_workspace/riva-tts-model-repo` model repo location where we've preloaded the TTS models
#
# Save your work.
#
# If you're not sure what to change, take a peek at the [solution](solutions/ex7.1.2_config.sh).

# %% [markdown]
# Check your work.  The `diff` comparison in the following cell should have no output.

# %%
# Check your work
# !diff solutions/ex7.1.2_config.sh dli_workspace/riva_quickstart/config.sh
# Out:
# 32c32
# < language_code=("en-US")
# ---
# > language_code=("en-US" "es-US")
# 67c67
# < riva_model_loc="/dli_workspace/riva-tts-model-repo"
# ---
# > riva_model_loc="/dli_workspace/riva-asr-model-repo"

# %% [markdown]
# ## 7.1.3 Riva Start Services
#
# The `riva_init.sh` script downloads the Riva containers needed, downloads models listed in `config.sh`, and optimizes  models as required with [NVIDIA TensorRT](https://developer.nvidia.com/tensorrt). Since we've already used the ServiceMaker `riva-deploy` tool to optimize the models we are using, `riva_init.sh` won't have much to do, but it is provided here for completeness.
#
# The `riva_start.sh` script starts the server.

# %%
# Initialize Riva (5 minutes)
# Models have been preloaded, so TensorRT builds ("deployment") will be skipped
# !cd $RIVA_QS && bash riva_init.sh config.sh
# Out:
# Logging into NGC docker registry if necessary...
# Pulling required docker images if necessary...
# Note: This may take some time, depending on the speed of your Internet connection.
# > Pulling Riva Speech Server images.
#   > Image nvcr.io/nvidia/riva/riva-speech:2.8.1 exists. Skipping.
#   > Image nvcr.io/nvidia/riva/riva-speech:2.8.1-servicemaker exists. Skipping.
#
# Downloading models (RMIRs) from NGC...
# Note: this may take some time, depending on the speed of your Internet connection.
# To skip this process and use existing RMIRs set the location and corresponding flag in config.sh.
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
#
# ==========================
# === Riva Speech Skills ===
# ==========================
#
# NVIDIA Release  (build 49655095)
# Copyright (c) 2016-2022, NVIDIA CORPORATION & AFFILIATES. All rights reserved.
#
# Copyright (c) 2018-2022, NVIDIA CORPORATION & AFFILIATES. All rights reserved.
#
# https://developer.nvidia.com/tensorrt
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the NVIDIA Deep Learning Container License.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/ngc/nvidia-deep-learning-container-license
#
# To install Python sample dependencies, run /opt/tensorrt/python/python_setup.sh
#
# To install the open-source samples corresponding to this TensorRT release version
# run /opt/tensorrt/install_opensource.sh.  To build the open source parsers,
# plugins, and samples for current top-of-tree on master or a different branch,
# run /opt/tensorrt/install_opensource.sh -b <branch>
# See https://github.com/NVIDIA/TensorRT for more information.
#
# NOTE: CUDA Forward Compatibility mode ENABLED.
#   Using CUDA 11.8 driver version 520.61.05 with kernel driver version 510.47.03.
#   See https://docs.nvidia.com/deploy/cuda-compatibility/ for details.
#
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# /data/artifacts /opt/riva
# Directory rmir_tts_fastpitch_hifigan_en_us_ipa_v2.8.0 already exists, skipping. Use '--force' option to override.
# /opt/riva
#
# + [[ non-tegra != \t\e\g\r\a ]]
# + [[ non-tegra == \t\e\g\r\a ]]
# + echo 'Converting RMIRs at /dli_workspace/riva-asr-model-repo/rmir to Riva Model repository.'
# Converting RMIRs at /dli_workspace/riva-asr-model-repo/rmir to Riva Model repository.
# + docker run --init -it --rm --gpus '"device=0"' -v /dli_workspace/riva-asr-model-repo:/data -e MODEL_DEPLOY_KEY=tlt_encode --name riva-service-maker --network host nvcr.io/nvidia/riva/riva-speech:2.8.1-servicemaker deploy_all_models /data/rmir /data/models
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
#
# ==========================
# === Riva Speech Skills ===
# ==========================
#
# NVIDIA Release  (build 49655095)
# Copyright (c) 2016-2022, NVIDIA CORPORATION & AFFILIATES. All rights reserved.
#
# Copyright (c) 2018-2022, NVIDIA CORPORATION & AFFILIATES. All rights reserved.
#
# https://developer.nvidia.com/tensorrt
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the NVIDIA Deep Learning Container License.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/ngc/nvidia-deep-learning-container-license
#
# To install Python sample dependencies, run /opt/tensorrt/python/python_setup.sh
#
# To install the open-source samples corresponding to this TensorRT release version
# run /opt/tensorrt/install_opensource.sh.  To build the open source parsers,
# plugins, and samples for current top-of-tree on master or a different branch,
# run /opt/tensorrt/install_opensource.sh -b <branch>
# See https://github.com/NVIDIA/TensorRT for more information.
#
# NOTE: CUDA Forward Compatibility mode ENABLED.
#   Using CUDA 11.8 driver version 520.61.05 with kernel driver version 510.47.03.
#   See https://docs.nvidia.com/deploy/cuda-compatibility/ for details.
#
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# 2025-07-17 12:06:35,868 [INFO] Writing Riva model repository to '/data/models'...
# 2025-07-17 12:06:35,868 [INFO] The riva model repo target directory is /data/models
# 2025-07-17 12:06:43,270 [INFO] Using obey-precision pass with fp16 TRT
# 2025-07-17 12:06:43,270 [WARNING] /data/models/riva-trt-riva_ner-nn-bert-base-uncased already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-riva_ner-nn-bert-base-uncased
# 2025-07-17 12:06:43,270 [WARNING] /data/models/token_classification_tokenizer-en-US already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/token_classification_tokenizer-en-US
# 2025-07-17 12:06:43,271 [WARNING] /data/models/token_classification_label_tokens already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/token_classification_label_tokens
# 2025-07-17 12:06:43,271 [WARNING] /data/models/token_classification_detokenizer already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/token_classification_detokenizer
# 2025-07-17 12:06:43,271 [WARNING] /data/models/riva_ner already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_ner
# 2025-07-17 12:06:51,941 [INFO] Using obey-precision pass with fp16 TRT
# 2025-07-17 12:06:51,942 [WARNING] /data/models/riva-trt-riva_intent_weather-nn-bert-base-uncased already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-riva_intent_weather-nn-bert-base-uncased
# 2025-07-17 12:06:51,942 [WARNING] /data/models/intent_slot_tokenizer-en-US-weather already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/intent_slot_tokenizer-en-US-weather
# 2025-07-17 12:06:51,942 [WARNING] /data/models/intent_slot_label_tokens_weather already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/intent_slot_label_tokens_weather
# 2025-07-17 12:06:51,942 [WARNING] /data/models/intent_slot_detokenizer already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/intent_slot_detokenizer
# 2025-07-17 12:06:51,942 [WARNING] /data/models/riva_intent_weather already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_intent_weather
# 2025-07-17 12:07:04,389 [INFO] Using obey-precision pass with fp16 TRT
# 2025-07-17 12:07:04,390 [WARNING] /data/models/riva-trt-conformer-es-US-asr-streaming-am-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-conformer-es-US-asr-streaming-am-streaming
# 2025-07-17 12:07:04,390 [WARNING] /data/models/conformer-es-US-asr-streaming-feature-extractor-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-es-US-asr-streaming-feature-extractor-streaming
# 2025-07-17 12:07:04,390 [WARNING] /data/models/conformer-es-US-asr-streaming-endpointing-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-es-US-asr-streaming-endpointing-streaming
# 2025-07-17 12:07:04,390 [WARNING] /data/models/conformer-es-US-asr-streaming-ctc-decoder-cpu-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-es-US-asr-streaming-ctc-decoder-cpu-streaming
# 2025-07-17 12:07:04,390 [WARNING] /data/models/conformer-es-US-asr-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-es-US-asr-streaming
# ^C
# Traceback (most recent call last):
#   File "/usr/local/bin/riva-deploy", line 8, in <module>
#     sys.exit(deploy_from_rmir())
#   File "/usr/local/lib/python3.8/dist-packages/servicemaker/cli/deploy.py", line 84, in deploy_from_rmir
#     rmir = RMIR.restore_from(model_filename, encryption_key=model_key)
#   File "/usr/local/lib/python3.8/dist-packages/servicemaker/rmir/rmir.py", line 276, in restore_from
#     rmir._read()
#   File "/usr/local/lib/python3.8/dist-packages/servicemaker/rmir/rmir.py", line 179, in _read
#     read_eff_manifest(self, self.filename)
#   File "/usr/local/lib/python3.8/dist-packages/servicemaker/readers/tlt.py", line 65, in read_eff_manifest
#     manifest = Archive.restore_manifest(restore_path=source_file)
#   File "<frozen eff.core.archive>", line 648, in restore_manifest
#   File "<frozen eff.core.archive>", line 759, in extract
#   File "/usr/lib/python3.8/tarfile.py", line 2060, in extract
#     tarinfo = self.getmember(member)
#   File "/usr/lib/python3.8/tarfile.py", line 1780, in getmember
#     tarinfo = self._getmember(name)
#   File "/usr/lib/python3.8/tarfile.py", line 2356, in _getmember
#     members = self.getmembers()
#   File "/usr/lib/python3.8/tarfile.py", line 1791, in getmembers
#     self._load()        # all members, we first have to
#   File "/usr/lib/python3.8/tarfile.py", line 2379, in _load
#     tarinfo = self.next()
#   File "/usr/lib/python3.8/tarfile.py", line 2310, in next
#     self.fileobj.seek(self.offset - 1)
#   File "/usr/lib/python3.8/gzip.py", line 384, in seek
#     return self._buffer.seek(offset, whence)
#   File "/usr/lib/python3.8/_compression.py", line 143, in seek
#     data = self.read(min(io.DEFAULT_BUFFER_SIZE, offset))
#   File "/usr/lib/python3.8/gzip.py", line 487, in read
#     uncompress = self._decompressor.decompress(buf, size)
# KeyboardInterrupt

# %%
# Run Riva Start. This will start the server. (15 seconds)
# !cd $RIVA_QS && bash riva_start.sh config.sh
# Out:
# Riva Speech already running. Skipping...
# Riva server is ready...

# %% [markdown]
# Riva ASR services should be running when you get "Riva server is ready..."
#
# ##### Troubleshooting:
# If it failed, open a terminal and clean the Riva model repository with:
#
# ```bash
# cd /dli_workspace/riva_quickstart && bash riva_clean.sh config.sh
# ```
#
# Run Riva Start Services as explained previously.

# %% [markdown]
# ## 7.1.4 Riva Available Services Check
#
# To check the exposed Riva services, run the `docker logs riva-speech` command.
#
# You should see the following models ready:

# %% [markdown]
# ```
# +----------------------------------------+---------+--------+
# | Model                                  | Version | Status |
# +----------------------------------------+---------+--------+
# | fastpitch_hifigan_ensemble-English-US  | 1       | READY  |
# | riva-onnx-fastpitch_encoder-English-US | 1       | READY  |
# | riva-trt-hifigan-English-US            | 1       | READY  |
# | spectrogram_chunker-English-US         | 1       | READY  |
# | tts_postprocessor-English-US           | 1       | READY  |
# | tts_preprocessor-English-US            | 1       | READY  |
# +----------------------------------------+---------+--------+
# ```

# %%
# !docker logs riva-speech
# Out:
# ==========================
# === Riva Speech Skills ===
# ==========================
#
# NVIDIA Release  (build 49655088)
#
# Copyright (c) 2018-2022, NVIDIA CORPORATION & AFFILIATES. All rights reserved.
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the NVIDIA Deep Learning Container License.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/ngc/nvidia-deep-learning-container-license
#
# NOTE: CUDA Forward Compatibility mode ENABLED.
#   Using CUDA 11.8 driver version 520.61.05 with kernel driver version 510.47.03.
#   See https://docs.nvidia.com/deploy/cuda-compatibility/ for details.
#
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# Warning: '--strict-model-config' has been deprecated! Please use '--disable-auto-complete-config' instead.
# I0717 11:22:45.391499 104 pinned_memory_manager.cc:240] Pinned memory pool is created at '0x7f7548000000' with size 268435456
# I0717 11:22:45.392209 104 cuda_memory_manager.cc:105] CUDA memory pool is created on device 0 with size 1000000000
# I0717 11:22:45.424363 104 model_lifecycle.cc:459] loading: conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline:1
# I0717 11:22:45.424438 104 model_lifecycle.cc:459] loading: conformer-en-US-asr-offline-endpointing-streaming-offline:1
# I0717 11:22:45.424539 104 model_lifecycle.cc:459] loading: conformer-en-US-asr-offline-feature-extractor-streaming-offline:1
# I0717 11:22:45.424625 104 model_lifecycle.cc:459] loading: conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming:1
# I0717 11:22:45.424722 104 model_lifecycle.cc:459] loading: conformer-en-US-asr-streaming-endpointing-streaming:1
# I0717 11:22:45.424786 104 model_lifecycle.cc:459] loading: conformer-en-US-asr-streaming-feature-extractor-streaming:1
# I0717 11:22:45.424840 104 model_lifecycle.cc:459] loading: conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline:1
# I0717 11:22:45.424944 104 model_lifecycle.cc:459] loading: conformer-es-US-asr-offline-endpointing-streaming-offline:1
# I0717 11:22:45.425137 104 model_lifecycle.cc:459] loading: conformer-es-US-asr-offline-feature-extractor-streaming-offline:1
# I0717 11:22:45.425184 104 model_lifecycle.cc:459] loading: conformer-es-US-asr-streaming-ctc-decoder-cpu-streaming:1
# I0717 11:22:45.425229 104 model_lifecycle.cc:459] loading: conformer-es-US-asr-streaming-endpointing-streaming:1
# I0717 11:22:45.425263 104 model_lifecycle.cc:459] loading: conformer-es-US-asr-streaming-feature-extractor-streaming:1
# I0717 11:22:45.425303 104 model_lifecycle.cc:459] loading: intent_slot_detokenizer:1
# I0717 11:22:45.425341 104 model_lifecycle.cc:459] loading: intent_slot_label_tokens_weather:1
# I0717 11:22:45.425379 104 model_lifecycle.cc:459] loading: intent_slot_tokenizer-en-US-weather:1
# I0717 11:22:45.425427 104 model_lifecycle.cc:459] loading: riva-punctuation-en-US:1
# I0717 11:22:45.425466 104 model_lifecycle.cc:459] loading: riva-punctuation-es-US:1
# I0717 11:22:45.425496 104 model_lifecycle.cc:459] loading: riva-trt-conformer-en-US-asr-offline-am-streaming-offline:1
# I0717 11:22:45.425521 104 model_lifecycle.cc:459] loading: riva-trt-conformer-en-US-asr-streaming-am-streaming:1
# I0717 11:22:45.425545 104 model_lifecycle.cc:459] loading: riva-trt-conformer-es-US-asr-offline-am-streaming-offline:1
# I0717 11:22:45.425586 104 model_lifecycle.cc:459] loading: riva-trt-conformer-es-US-asr-streaming-am-streaming:1
# I0717 11:22:45.425605 104 model_lifecycle.cc:459] loading: riva-trt-riva-punctuation-en-US-nn-bert-base-uncased:1
# I0717 11:22:45.425626 104 model_lifecycle.cc:459] loading: riva-trt-riva-punctuation-es-US-nn-bert-base-multilingual-uncased:1
# I0717 11:22:45.425657 104 model_lifecycle.cc:459] loading: riva-trt-riva_intent_weather-nn-bert-base-uncased:1
# I0717 11:22:45.425686 104 model_lifecycle.cc:459] loading: riva-trt-riva_ner-nn-bert-base-uncased:1
# I0717 11:22:45.425722 104 model_lifecycle.cc:459] loading: token_classification_detokenizer:1
# I0717 11:22:45.425756 104 model_lifecycle.cc:459] loading: token_classification_label_tokens:1
# I0717 11:22:45.425782 104 model_lifecycle.cc:459] loading: token_classification_tokenizer-en-US:1
# I0717 11:22:45.509101 104 feature-extractor.cc:400] TRITONBACKEND_ModelInitialize: conformer-en-US-asr-offline-feature-extractor-streaming-offline (version 1)
# I0717 11:22:45.544550 104 backend_model.cc:303] model configuration:
# {
#     "name": "conformer-en-US-asr-offline-feature-extractor-streaming-offline",
#     "platform": "",
#     "backend": "riva_asr_features",
#     "version_policy": {
#         "latest": {
#             "num_versions": 1
#         }
#     },
#     "max_batch_size": 512,
#     "input": [
#         {
#             "name": "AUDIO_SIGNAL",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "SAMPLE_RATE",
#             "data_type": "TYPE_UINT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         }
#     ],
#     "output": [
#         {
#             "name": "AUDIO_FEATURES",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 80,
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "AUDIO_PROCESSED",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "AUDIO_FEATURES_LENGTH",
#             "data_type": "TYPE_INT32",
#             "dims": [
#                 1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         }
#     ],
#     "batch_input": [],
#     "batch_output": [],
#     "optimization": {
#         "graph": {
#             "level": 0
#         },
#         "priority": "PRIORITY_DEFAULT",
#         "cuda": {
#             "graphs": false,
#             "busy_wait_events": false,
#             "graph_spec": [],
#             "output_copy_stream": true
#         },
#         "input_pinned_memory": {
#             "enable": true
#         },
#         "output_pinned_memory": {
#             "enable": true
#         },
#         "gather_kernel_buffer_threshold": 0,
#         "eager_batching": false
#     },
#     "sequence_batching": {
#         "oldest": {
#             "max_candidate_sequences": 512,
#             "preferred_batch_size": [
#                 256,
#                 512
#             ],
#             "max_queue_delay_microseconds": 1000
#         },
#         "max_sequence_idle_microseconds": 60000000,
#         "control_input": [
#             {
#                 "name": "START",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_START",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "READY",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_READY",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "END",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_END",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "CORRID",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_CORRID",
#                         "int32_false_true": [],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_UINT64"
#                     }
#                 ]
#             }
#         ],
#         "state": []
#     },
#     "instance_group": [
#         {
#             "name": "conformer-en-US-asr-offline-feature-extractor-streaming-offline_0",
#             "kind": "KIND_GPU",
#             "count": 1,
#             "gpus": [
#                 0
#             ],
#             "secondary_devices": [],
#             "profile": [],
#             "passive": false,
#             "host_policy": ""
#         }
#     ],
#     "default_model_filename": "",
#     "cc_model_filenames": {},
#     "metric_tags": {},
#     "parameters": {
#         "transpose": {
#             "string_value": "False"
#         },
#         "gain": {
#             "string_value": "1.0"
#         },
#         "use_utterance_norm_params": {
#             "string_value": "False"
#         },
#         "mean": {
#             "string_value": "-11.4412,  -9.9334,  -9.1292,  -9.0365,  -9.2804,  -9.5643,  -9.7342, -9.6925,  -9.6333,  -9.2808,  -9.1887,  -9.1422,  -9.1397,  -9.2028, -9.2749,  -9.4776,  -9.9185, -10.1557, -10.3800, -10.5067, -10.3190, -10.4728, -10.5529, -10.6402, -10.6440, -10.5113, -10.7395, -10.7870, -10.6074, -10.5033, -10.8278, -10.6384, -10.8481, -10.6875, -10.5454, -10.4747, -10.5165, -10.4930, -10.3413, -10.3472, -10.3735, -10.6830, -10.8813, -10.6338, -10.3856, -10.7727, -10.8957, -10.8068, -10.7373, -10.6108, -10.3405, -10.2889, -10.3922, -10.4946, -10.3367, -10.4164, -10.9949, -10.7196, -10.3971, -10.1734,  -9.9257,  -9.6557,  -9.1761, -9.6653,  -9.7876,  -9.7230,  -9.7792,  -9.7056,  -9.2702,  -9.4650, -9.2755,  -9.1369,  -9.1174,  -8.9197,  -8.5394,  -8.2614,  -8.1353, -8.1422,  -8.3430,  -8.6655"
#         },
#         "streaming": {
#             "string_value": "True"
#         },
#         "dither": {
#             "string_value": "0.0"
#         },
#         "sample_rate": {
#             "string_value": "16000"
#         },
#         "left_padding_size": {
#             "string_value": "1.6"
#         },
#         "precalc_norm_params": {
#             "string_value": "False"
#         },
#         "apply_normalization": {
#             "string_value": "True"
#         },
#         "precalc_norm_time_steps": {
#             "string_value": "0"
#         },
#         "max_execution_batch_size": {
#             "string_value": "512"
#         },
#         "stddev_floor": {
#             "string_value": "1e-05"
#         },
#         "num_features": {
#             "string_value": "80"
#         },
#         "norm_per_feature": {
#             "string_value": "True"
#         },
#         "window_stride": {
#             "string_value": "0.01"
#         },
#         "right_padding_size": {
#             "string_value": "1.6"
#         },
#         "chunk_size": {
#             "string_value": "4.8"
#         },
#         "stddev": {
#             "string_value": "2.2668, 3.1642, 3.7079, 3.7642, 3.5349, 3.5901, 3.7640, 3.8424, 4.0145, 4.1475, 4.0457, 3.9048, 3.7709, 3.6117, 3.3188, 3.1489, 3.0615, 3.0362, 2.9929, 3.0500, 3.0341, 3.0484, 3.0103, 2.9474, 2.9128, 2.8669, 2.8332, 2.9411, 3.0378, 3.0712, 3.0190, 2.9992, 3.0124, 3.0024, 3.0275, 3.0870, 3.0656, 3.0142, 3.0493, 3.1373, 3.1135, 3.0675, 2.8828, 2.7018, 2.6296, 2.8826, 2.9325, 2.9288, 2.9271, 2.9890, 3.0137, 2.9855, 3.0839, 2.9319, 2.3512, 2.3795, 2.6191, 2.7555, 2.9326, 2.9931, 3.1543, 3.0855, 2.6820, 3.0566, 3.1272, 3.1663, 3.1836, 3.0018, 2.9089, 3.1727, 3.1626, 3.1086, 2.9804, 3.1107, 3.2998, 3.3697, 3.3716, 3.2487, 3.1597, 3.1181"
#         },
#         "window_size": {
#             "string_value": "0.025"
#         }
#     },
#     "model_warmup": [],
#     "model_transaction_policy": {
#         "decoupled": false
#     }
# }
# I0717 11:22:45.544642 104 feature-extractor.cc:400] TRITONBACKEND_ModelInitialize: conformer-en-US-asr-streaming-feature-extractor-streaming (version 1)
# I0717 11:22:45.545497 104 backend_model.cc:303] model configuration:
# {
#     "name": "conformer-en-US-asr-streaming-feature-extractor-streaming",
#     "platform": "",
#     "backend": "riva_asr_features",
#     "version_policy": {
#         "latest": {
#             "num_versions": 1
#         }
#     },
#     "max_batch_size": 1024,
#     "input": [
#         {
#             "name": "AUDIO_SIGNAL",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "SAMPLE_RATE",
#             "data_type": "TYPE_UINT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         }
#     ],
#     "output": [
#         {
#             "name": "AUDIO_FEATURES",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 80,
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "AUDIO_PROCESSED",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "AUDIO_FEATURES_LENGTH",
#             "data_type": "TYPE_INT32",
#             "dims": [
#                 1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         }
#     ],
#     "batch_input": [],
#     "batch_output": [],
#     "optimization": {
#         "graph": {
#             "level": 0
#         },
#         "priority": "PRIORITY_DEFAULT",
#         "cuda": {
#             "graphs": false,
#             "busy_wait_events": false,
#             "graph_spec": [],
#             "output_copy_stream": true
#         },
#         "input_pinned_memory": {
#             "enable": true
#         },
#         "output_pinned_memory": {
#             "enable": true
#         },
#         "gather_kernel_buffer_threshold": 0,
#         "eager_batching": false
#     },
#     "sequence_batching": {
#         "oldest": {
#             "max_candidate_sequences": 1024,
#             "preferred_batch_size": [
#                 256,
#                 512
#             ],
#             "max_queue_delay_microseconds": 1000
#         },
#         "max_sequence_idle_microseconds": 60000000,
#         "control_input": [
#             {
#                 "name": "START",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_START",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "READY",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_READY",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "END",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_END",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "CORRID",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_CORRID",
#                         "int32_false_true": [],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_UINT64"
#                     }
#                 ]
#             }
#         ],
#         "state": []
#     },
#     "instance_group": [
#         {
#             "name": "conformer-en-US-asr-streaming-feature-extractor-streaming_0",
#             "kind": "KIND_GPU",
#             "count": 1,
#             "gpus": [
#                 0
#             ],
#             "secondary_devices": [],
#             "profile": [],
#             "passive": false,
#             "host_policy": ""
#         }
#     ],
#     "default_model_filename": "",
#     "cc_model_filenames": {},
#     "metric_tags": {},
#     "parameters": {
#         "precalc_norm_time_steps": {
#             "string_value": "0"
#         },
#         "transpose": {
#             "string_value": "False"
#         },
#         "norm_per_feature": {
#             "string_value": "True"
#         },
#         "use_utterance_norm_params": {
#             "string_value": "False"
#         },
#         "num_features": {
#             "string_value": "80"
#         },
#         "precalc_norm_params": {
#             "string_value": "False"
#         },
#         "sample_rate": {
#             "string_value": "16000"
#         },
#         "stddev": {
#             "string_value": "2.2668, 3.1642, 3.7079, 3.7642, 3.5349, 3.5901, 3.7640, 3.8424, 4.0145, 4.1475, 4.0457, 3.9048, 3.7709, 3.6117, 3.3188, 3.1489, 3.0615, 3.0362, 2.9929, 3.0500, 3.0341, 3.0484, 3.0103, 2.9474, 2.9128, 2.8669, 2.8332, 2.9411, 3.0378, 3.0712, 3.0190, 2.9992, 3.0124, 3.0024, 3.0275, 3.0870, 3.0656, 3.0142, 3.0493, 3.1373, 3.1135, 3.0675, 2.8828, 2.7018, 2.6296, 2.8826, 2.9325, 2.9288, 2.9271, 2.9890, 3.0137, 2.9855, 3.0839, 2.9319, 2.3512, 2.3795, 2.6191, 2.7555, 2.9326, 2.9931, 3.1543, 3.0855, 2.6820, 3.0566, 3.1272, 3.1663, 3.1836, 3.0018, 2.9089, 3.1727, 3.1626, 3.1086, 2.9804, 3.1107, 3.2998, 3.3697, 3.3716, 3.2487, 3.1597, 3.1181"
#         },
#         "stddev_floor": {
#             "string_value": "1e-05"
#         },
#         "mean": {
#             "string_value": "-11.4412,  -9.9334,  -9.1292,  -9.0365,  -9.2804,  -9.5643,  -9.7342, -9.6925,  -9.6333,  -9.2808,  -9.1887,  -9.1422,  -9.1397,  -9.2028, -9.2749,  -9.4776,  -9.9185, -10.1557, -10.3800, -10.5067, -10.3190, -10.4728, -10.5529, -10.6402, -10.6440, -10.5113, -10.7395, -10.7870, -10.6074, -10.5033, -10.8278, -10.6384, -10.8481, -10.6875, -10.5454, -10.4747, -10.5165, -10.4930, -10.3413, -10.3472, -10.3735, -10.6830, -10.8813, -10.6338, -10.3856, -10.7727, -10.8957, -10.8068, -10.7373, -10.6108, -10.3405, -10.2889, -10.3922, -10.4946, -10.3367, -10.4164, -10.9949, -10.7196, -10.3971, -10.1734,  -9.9257,  -9.6557,  -9.1761, -9.6653,  -9.7876,  -9.7230,  -9.7792,  -9.7056,  -9.2702,  -9.4650, -9.2755,  -9.1369,  -9.1174,  -8.9197,  -8.5394,  -8.2614,  -8.1353, -8.1422,  -8.3430,  -8.6655"
#         },
#         "left_padding_size": {
#             "string_value": "1.92"
#         },
#         "max_execution_batch_size": {
#             "string_value": "1024"
#         },
#         "apply_normalization": {
#             "string_value": "True"
#         },
#         "window_size": {
#             "string_value": "0.025"
#         },
#         "gain": {
#             "string_value": "1.0"
#         },
#         "streaming": {
#             "string_value": "True"
#         },
#         "dither": {
#             "string_value": "0.0"
#         },
#         "window_stride": {
#             "string_value": "0.01"
#         },
#         "chunk_size": {
#             "string_value": "0.16"
#         },
#         "right_padding_size": {
#             "string_value": "1.92"
#         }
#     },
#     "model_warmup": [],
#     "model_transaction_policy": {
#         "decoupled": false
#     }
# }
# I0717 11:22:45.548429 104 ctc-decoder-library.cc:20] TRITONBACKEND_ModelInitialize: conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline (version 1)
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# W0717 11:22:45.549865   116 parameter_parser.cc:144] Parameter 'append_space_to_transcripts' set but unused.
# W0717 11:22:45.549885   116 parameter_parser.cc:144] Parameter 'beam_size' set but unused.
# W0717 11:22:45.549892   116 parameter_parser.cc:144] Parameter 'beam_size_token' set but unused.
# W0717 11:22:45.549896   116 parameter_parser.cc:144] Parameter 'beam_threshold' set but unused.
# W0717 11:22:45.549898   116 parameter_parser.cc:144] Parameter 'blank_token' set but unused.
# W0717 11:22:45.549901   116 parameter_parser.cc:144] Parameter 'decoder_num_worker_threads' set but unused.
# W0717 11:22:45.549904   116 parameter_parser.cc:144] Parameter 'forerunner_beam_size' set but unused.
# W0717 11:22:45.549906   116 parameter_parser.cc:144] Parameter 'forerunner_beam_size_token' set but unused.
# W0717 11:22:45.549909   116 parameter_parser.cc:144] Parameter 'forerunner_beam_threshold' set but unused.
# W0717 11:22:45.549911   116 parameter_parser.cc:144] Parameter 'forerunner_use_lm' set but unused.
# W0717 11:22:45.549914   116 parameter_parser.cc:144] Parameter 'language_model_file' set but unused.
# W0717 11:22:45.549916   116 parameter_parser.cc:144] Parameter 'lexicon_file' set but unused.
# W0717 11:22:45.549919   116 parameter_parser.cc:144] Parameter 'lm_weight' set but unused.
# W0717 11:22:45.549921   116 parameter_parser.cc:144] Parameter 'log_add' set but unused.
# W0717 11:22:45.549923   116 parameter_parser.cc:144] Parameter 'max_execution_batch_size' set but unused.
# W0717 11:22:45.549926   116 parameter_parser.cc:144] Parameter 'max_supported_transcripts' set but unused.
# W0717 11:22:45.549928   116 parameter_parser.cc:144] Parameter 'num_tokenization' set but unused.
# W0717 11:22:45.549932   116 parameter_parser.cc:144] Parameter 'profane_words_file' set but unused.
# W0717 11:22:45.549934   116 parameter_parser.cc:144] Parameter 'set_default_index_to_unk_token' set but unused.
# W0717 11:22:45.549937   116 parameter_parser.cc:144] Parameter 'sil_token' set but unused.
# W0717 11:22:45.549939   116 parameter_parser.cc:144] Parameter 'smearing_mode' set but unused.
# W0717 11:22:45.549942   116 parameter_parser.cc:144] Parameter 'tokenizer_model' set but unused.
# W0717 11:22:45.549944   116 parameter_parser.cc:144] Parameter 'unk_score' set but unused.
# W0717 11:22:45.549947   116 parameter_parser.cc:144] Parameter 'unk_token' set but unused.
# W0717 11:22:45.549949   116 parameter_parser.cc:144] Parameter 'vocab_file' set but unused.
# W0717 11:22:45.549952   116 parameter_parser.cc:144] Parameter 'word_insertion_score' set but unused.
# I0717 11:22:45.550857 104 backend_model.cc:303] model configuration:
# {
#     "name": "conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline",
#     "platform": "",
#     "backend": "riva_asr_decoder",
#     "version_policy": {
#         "latest": {
#             "num_versions": 1
#         }
#     },
#     "max_batch_size": 1024,
#     "input": [
#         {
#             "name": "CLASS_LOGITS",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1,
#                 257
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "END_FLAG",
#             "data_type": "TYPE_UINT32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 1
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "SEGMENTS_START_END",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1,
#                 2
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         },
#         {
#             "name": "CUSTOM_CONFIGURATION",
#             "data_type": "TYPE_STRING",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1,
#                 2
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         }
#     ],
#     "output": [
#         {
#             "name": "FINAL_TRANSCRIPTS",
#             "data_type": "TYPE_STRING",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "FINAL_TRANSCRIPTS_SCORE",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "FINAL_WORDS_START_END",
#             "data_type": "TYPE_INT32",
#             "dims": [
#                 -1,
#                 2
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "PARTIAL_TRANSCRIPTS",
#             "data_type": "TYPE_STRING",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "PARTIAL_TRANSCRIPTS_STABILITY",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "PARTIAL_WORDS_START_END",
#             "data_type": "TYPE_INT32",
#             "dims": [
#                 -1,
#                 2
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "FINAL_WORDS_SCORE",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         },
#         {
#             "name": "PARTIAL_WORDS_SCORE",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         }
#     ],
#     "batch_input": [],
#     "batch_output": [],
#     "optimization": {
#         "graph": {
#             "level": 0
#         },
#         "priority": "PRIORITY_DEFAULT",
#         "cuda": {
#             "graphs": false,
#             "busy_wait_events": false,
#             "graph_spec": [],
#             "output_copy_stream": true
#         },
#         "input_pinned_memory": {
#             "enable": true
#         },
#         "output_pinned_memory": {
#             "enable": true
#         },
#         "gather_kernel_buffer_threshold": 0,
#         "eager_batching": false
#     },
#     "sequence_batching": {
#         "oldest": {
#             "max_candidate_sequences": 1024,
#             "preferred_batch_size": [
#                 32,
#                 64
#             ],
#             "max_queue_delay_microseconds": 1000
#         },
#         "max_sequence_idle_microseconds": 60000000,
#         "control_input": [
#             {
#                 "name": "START",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_START",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "READY",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_READY",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "END",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_END",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "CORRID",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_CORRID",
#                         "int32_false_true": [],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_UINT64"
#                     }
#                 ]
#             }
#         ],
#         "state": []
#     },
#     "instance_group": [
#         {
#             "name": "conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline_0",
#             "kind": "KIND_CPU",
#             "count": 1,
#             "gpus": [],
#             "secondary_devices": [],
#             "profile": [],
#             "passive": false,
#             "host_policy": ""
#         }
#     ],
#     "default_model_filename": "",
#     "cc_model_filenames": {},
#     "metric_tags": {},
#     "parameters": {
#         "beam_size": {
#             "string_value": "16"
#         },
#         "sil_token": {
#             "string_value": "▁"
#         },
#         "unk_token": {
#             "string_value": "<unk>"
#         },
#         "chunk_size": {
#             "string_value": "4.8"
#         },
#         "max_supported_transcripts": {
#             "string_value": "1"
#         },
#         "max_execution_batch_size": {
#             "string_value": "1024"
#         },
#         "log_add": {
#             "string_value": "True"
#         },
#         "forerunner_use_lm": {
#             "string_value": "true"
#         },
#         "smearing_mode": {
#             "string_value": "max"
#         },
#         "set_default_index_to_unk_token": {
#             "string_value": "False"
#         },
#         "forerunner_beam_size_token": {
#             "string_value": "8"
#         },
#         "lm_weight": {
#             "string_value": "0.2"
#         },
#         "beam_size_token": {
#             "string_value": "16"
#         },
#         "vocab_file": {
#             "string_value": "/data/models/conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline/1/riva_decoder_vocabulary.txt"
#         },
#         "use_subword": {
#             "string_value": "True"
#         },
#         "right_padding_size": {
#             "string_value": "1.6"
#         },
#         "unk_score": {
#             "string_value": "-inf"
#         },
#         "streaming": {
#             "string_value": "True"
#         },
#         "decoder_type": {
#             "string_value": "flashlight"
#         },
#         "left_padding_size": {
#             "string_value": "1.6"
#         },
#         "profane_words_file": {
#             "string_value": ""
#         },
#         "append_space_to_transcripts": {
#             "string_value": "True"
#         },
#         "language_model_file": {
#             "string_value": "/data/models/conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline/1/asr_set_2.0_4gram.bin"
#         },
#         "decoder_num_worker_threads": {
#             "string_value": "-1"
#         },
#         "beam_threshold": {
#             "string_value": "20.0"
#         },
#         "forerunner_beam_threshold": {
#             "string_value": "10.0"
#         },
#         "lexicon_file": {
#             "string_value": "/data/models/conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline/1/lexicon.txt"
#         },
#         "num_tokenization": {
#             "string_value": "1"
#         },
#         "tokenizer_model": {
#             "string_value": "/data/models/conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline/1/52caef77990a4f59bc46c083d3698dcf_tokenizer.model"
#         },
#         "forerunner_beam_size": {
#             "string_value": "8"
#         },
#         "asr_model_delay": {
#             "string_value": "0"
#         },
#         "word_insertion_score": {
#             "string_value": "0.2"
#         },
#         "blank_token": {
#             "string_value": "#"
#         },
#         "ms_per_timestep": {
#             "string_value": "40"
#         }
#     },
#     "model_warmup": [],
#     "model_transaction_policy": {
#         "decoupled": false
#     }
# }
# I0717 11:22:45.550943 104 endpointing_library.cc:18] TRITONBACKEND_ModelInitialize: conformer-en-US-asr-offline-endpointing-streaming-offline (version 1)
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# W0717 11:22:45.551479   111 parameter_parser.cc:144] Parameter 'chunk_size' set but unused.
# W0717 11:22:45.551504   111 parameter_parser.cc:144] Parameter 'ms_per_timestep' set but unused.
# W0717 11:22:45.551507   111 parameter_parser.cc:144] Parameter 'residue_blanks_at_end' set but unused.
# W0717 11:22:45.551510   111 parameter_parser.cc:144] Parameter 'residue_blanks_at_start' set but unused.
# W0717 11:22:45.551512   111 parameter_parser.cc:144] Parameter 'start_history' set but unused.
# W0717 11:22:45.551515   111 parameter_parser.cc:144] Parameter 'start_th' set but unused.
# W0717 11:22:45.551518   111 parameter_parser.cc:144] Parameter 'stop_history' set but unused.
# W0717 11:22:45.551520   111 parameter_parser.cc:144] Parameter 'stop_th' set but unused.
# W0717 11:22:45.551523   111 parameter_parser.cc:144] Parameter 'streaming' set but unused.
# W0717 11:22:45.551525   111 parameter_parser.cc:144] Parameter 'use_subword' set but unused.
# W0717 11:22:45.551528   111 parameter_parser.cc:144] Parameter 'vocab_file' set but unused.
# I0717 11:22:45.552099 104 backend_model.cc:303] model configuration:
# {
#     "name": "conformer-en-US-asr-offline-endpointing-streaming-offline",
#     "platform": "",
#     "backend": "riva_asr_endpointing",
#     "version_policy": {
#         "latest": {
#             "num_versions": 1
#         }
#     },
#     "max_batch_size": 2048,
#     "input": [
#         {
#             "name": "CLASS_LOGITS",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1,
#                 257
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         }
#     ],
#     "output": [
#         {
#             "name": "SEGMENTS_START_END",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1,
#                 2
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         }
#     ],
#     "batch_input": [],
#     "batch_output": [],
#     "optimization": {
#         "graph": {
#             "level": 0
#         },
#         "priority": "PRIORITY_DEFAULT",
#         "cuda": {
#             "graphs": false,
#             "busy_wait_events": false,
#             "graph_spec": [],
#             "output_copy_stream": true
#         },
#         "input_pinned_memory": {
#             "enable": true
#         },
#         "output_pinned_memory": {
#             "enable": true
#         },
#         "gather_kernel_buffer_threshold": 0,
#         "eager_batching": false
#     },
#     "sequence_batching": {
#         "max_sequence_idle_microseconds": 60000000,
#         "control_input": [
#             {
#                 "name": "START",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_START",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "READY",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_READY",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             }
#         ],
#         "state": []
#     },
#     "instance_group": [
#         {
#             "name": "conformer-en-US-asr-offline-endpointing-streaming-offline_0",
#             "kind": "KIND_CPU",
#             "count": 1,
#             "gpus": [],
#             "secondary_devices": [],
#             "profile": [],
#             "passive": false,
#             "host_policy": ""
#         }
#     ],
#     "default_model_filename": "",
#     "cc_model_filenames": {},
#     "metric_tags": {},
#     "parameters": {
#         "ms_per_timestep": {
#             "string_value": "40"
#         },
#         "stop_history": {
#             "string_value": "800"
#         },
#         "streaming": {
#             "string_value": "True"
#         },
#         "endpointing_type": {
#             "string_value": "greedy_ctc"
#         },
#         "chunk_size": {
#             "string_value": "4.8"
#         },
#         "start_history": {
#             "string_value": "200"
#         },
#         "residue_blanks_at_start": {
#             "string_value": "-2"
#         },
#         "vocab_file": {
#             "string_value": "/data/models/conformer-en-US-asr-offline-endpointing-streaming-offline/1/riva_decoder_vocabulary.txt"
#         },
#         "stop_th": {
#             "string_value": "0.98"
#         },
#         "use_subword": {
#             "string_value": "True"
#         },
#         "residue_blanks_at_end": {
#             "string_value": "0"
#         },
#         "start_th": {
#             "string_value": "0.2"
#         }
#     },
#     "model_warmup": [],
#     "model_transaction_policy": {
#         "decoupled": false
#     }
# }
# I0717 11:22:45.552185 104 feature-extractor.cc:402] TRITONBACKEND_ModelInstanceInitialize: conformer-en-US-asr-offline-feature-extractor-streaming-offline_0 (device 0)
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0717 11:22:46.432057 104 feature-extractor.cc:402] TRITONBACKEND_ModelInstanceInitialize: conformer-en-US-asr-streaming-feature-extractor-streaming_0 (device 0)
# I0717 11:22:46.433005 104 model_lifecycle.cc:693] successfully loaded 'conformer-en-US-asr-offline-feature-extractor-streaming-offline' version 1
# I0717 11:22:46.435769 104 endpointing_library.cc:18] TRITONBACKEND_ModelInitialize: conformer-en-US-asr-streaming-endpointing-streaming (version 1)
# W0717 11:22:46.436434   114 parameter_parser.cc:144] Parameter 'chunk_size' set but unused.
# W0717 11:22:46.436453   114 parameter_parser.cc:144] Parameter 'ms_per_timestep' set but unused.
# W0717 11:22:46.436456   114 parameter_parser.cc:144] Parameter 'residue_blanks_at_end' set but unused.
# W0717 11:22:46.436460   114 parameter_parser.cc:144] Parameter 'residue_blanks_at_start' set but unused.
# W0717 11:22:46.436461   114 parameter_parser.cc:144] Parameter 'start_history' set but unused.
# W0717 11:22:46.436465   114 parameter_parser.cc:144] Parameter 'start_th' set but unused.
# W0717 11:22:46.436466   114 parameter_parser.cc:144] Parameter 'stop_history' set but unused.
# W0717 11:22:46.436468   114 parameter_parser.cc:144] Parameter 'stop_th' set but unused.
# W0717 11:22:46.436471   114 parameter_parser.cc:144] Parameter 'streaming' set but unused.
# W0717 11:22:46.436477   114 parameter_parser.cc:144] Parameter 'use_subword' set but unused.
# W0717 11:22:46.436481   114 parameter_parser.cc:144] Parameter 'vocab_file' set but unused.
# I0717 11:22:46.436488 104 model_lifecycle.cc:693] successfully loaded 'conformer-en-US-asr-streaming-feature-extractor-streaming' version 1
# I0717 11:22:46.436998 104 backend_model.cc:303] model configuration:
# {
#     "name": "conformer-en-US-asr-streaming-endpointing-streaming",
#     "platform": "",
#     "backend": "riva_asr_endpointing",
#     "version_policy": {
#         "latest": {
#             "num_versions": 1
#         }
#     },
#     "max_batch_size": 2048,
#     "input": [
#         {
#             "name": "CLASS_LOGITS",
#             "data_type": "TYPE_FP32",
#             "format": "FORMAT_NONE",
#             "dims": [
#                 -1,
#                 257
#             ],
#             "is_shape_tensor": false,
#             "allow_ragged_batch": false,
#             "optional": false
#         }
#     ],
#     "output": [
#         {
#             "name": "SEGMENTS_START_END",
#             "data_type": "TYPE_FP32",
#             "dims": [
#                 -1,
#                 2
#             ],
#             "label_filename": "",
#             "is_shape_tensor": false
#         }
#     ],
#     "batch_input": [],
#     "batch_output": [],
#     "optimization": {
#         "graph": {
#             "level": 0
#         },
#         "priority": "PRIORITY_DEFAULT",
#         "cuda": {
#             "graphs": false,
#             "busy_wait_events": false,
#             "graph_spec": [],
#             "output_copy_stream": true
#         },
#         "input_pinned_memory": {
#             "enable": true
#         },
#         "output_pinned_memory": {
#             "enable": true
#         },
#         "gather_kernel_buffer_threshold": 0,
#         "eager_batching": false
#     },
#     "sequence_batching": {
#         "max_sequence_idle_microseconds": 60000000,
#         "control_input": [
#             {
#                 "name": "START",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_START",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             },
#             {
#                 "name": "READY",
#                 "control": [
#                     {
#                         "kind": "CONTROL_SEQUENCE_READY",
#                         "int32_false_true": [
#                             0,
#                             1
#                         ],
#                         "fp32_false_true": [],
#                         "bool_false_true": [],
#                         "data_type": "TYPE_INVALID"
#                     }
#                 ]
#             }
#         ],
#         "state": []
#     },
#     "instance_group": [
#         {
#             "name": "conformer-en-US-asr-streaming-endpointing-streaming_0",
#             "kind": "KIND_CPU",
#             "count": 1,
#             "gpus": [],
#             "secondary_devices": [],
#             "profile": [],
#             "passive": false,
#             "host_policy": ""
#         }
#     ],
#     "default_model_filename": "",
#     "cc_model_filenames": {},
#     "metric_tags": {},
#     "parameters": {
#         "start_th": {
#             "string_value": "0.2"
#         },
#         "endpointing_type": {
#             "string_value": "greedy_ctc"
#         },
#         "stop_th": {
#             "string_value": "0.98"
#         },
#         "ms_per_timestep": {
#             "string_value": "40"
#         },
#         "residue_blanks_at_start": {
#             "string_value": "-2"
#         },
#         "stop_history": {
#             "string_value": "800"
#         },
#         "start_history": {
#             "string_value": "200"
#         },
#         "vocab_file": {
#             "string_value": "/data/models/conformer-en-US-asr-streaming-endpointing-streaming/1/riva_decoder_vocabulary.txt"
#         },
#         "residue_blanks_at_end": {
#             "string_value": "0"
#         },
#         "chunk_size": {
#             "string_value": "0.16"
#         },
#         "use_subword": {
#             "string_value": "True"
#         },
#         "streaming": {
#             "string_value": "True"
#         }
#     },
#     "model_warmup": [],
#     "model_transaction_policy": {
#         "decoupled": false
#     }
# }
# I0717 11:22:46.437065 104 ctc-decoder-library.cc:23] TRITONBACKEND_ModelInstanceInitialize: conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline_0 (device 0)
#   > Riva waiting for Triton server to load all models...retrying in 1 second
# I0717 11:22:47.913128   116 ctc-decoder.cc:174] Beam Decoder initialized successfully!
# I0717 11:22:47.913248 104 ctc-decoder-library.cc:20] TRITONBACKEND_ModelInitialize: conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming (version 1)
# I0717 11:22:47.913745 104 model_lifecycle.cc:693] successfully loaded 'conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline' version 1
# W0717 11:22:47.914217   113 parameter_parser.cc:144] Parameter 'append_space_to_transcripts' set but unused.
# W0717 11:22:47.914237   113 parameter_parser.cc:144] Parameter 'beam_size' set but unused.
# W0717 11:22:47.914240   113 parameter_parser.cc:144] Parameter 'beam_size_token' set but unused.
# W0717 11:22:47.914242   113 parameter_parser.cc:144] Parameter 'beam_threshold' set but unused.
# W0717 11:22:47.914243   113 parameter_parser.cc:144] Parameter 'blank_token' set but unused.
# W0717 11:22:47.914245   113 parameter_parser.cc:144] Parameter 'decoder_num_worker_threads' set but unused.
# W0717 11:22:47.914247   113 parameter_parser.cc:144] Parameter 'forerunner_beam_size' set but unused.
# W0717 11:22:47.914248   113 parameter_parser.cc:144] Parameter 'forerunner_beam_size_token' set but unused.
# W0717 11:22:47.914250   113 parameter_parser.cc:144] Parameter 'forerunner_beam_threshold' set but unused.
# W0717 11:22:47.914252   113 parameter_parser.cc:144] Parameter 'forerunner_use_lm' set but unused.
# W0717 11:22:47.914253   113 parameter_parser.cc:144] Parameter 'language_model_file' set but unused.
# W0717 11:22:47.914255   113 parameter_parser.cc:144] Parameter 'lexicon_file' set but unused.
# W0717 11:22:47.914258   113 parameter_parser.cc:144] Parameter 'lm_weight' set but unused.
# W0717 11:22:47.914259   113 parameter_parser.cc:144] Parameter 'log_add' set but unused.
# W0717 11:22:47.914263   113 parameter_parser.cc:144] Parameter 'max_execution_batch_size' set but unused.
# W0717 11:22:47.914264   113 parameter_parser.cc:144] Parameter 'max_supported_transcripts' set but unused.
# W0717 11:22:47.914268   113 parameter_parser.cc:144] Parameter 'num_tokenization' set but unused.
# W0717 11:22:47.914273   113 parameter_parser.cc:144] Parameter 'profane_words_file' set but unused.
# W0717 11:22:47.914294   113 parameter_parser.cc:144] Parameter 'set_default_index_to_unk_token' set but unused.
# W0717 11:22:47.914296   113 parameter_parser.cc:144] Parameter 'sil_token' set but unused.
# W0717 11:22:47.914299   113 parameter_parser.cc:144] Parameter 'smearing_mode' set but unused.
# W0717 11:22:47.914301   113 parameter_parser.cc:144] Parameter 'tokenizer_model' set but unused.
# W0717 11:22:47.914312   113 parameter_parser.cc:144] Parameter 'unk_score' set but unused.
# W0717 11:22:47.914315   113 parameter_parser.cc:144] Parameter 'unk_token' set but unused.
# W0717 11:22:47.914319   113 parameter_parser.cc:144] Parameter 'vocab_file' set but unused.
# W0717 11:22:47.914321   113 parameter_parser.cc:144] Parameter 'word_insertion_score' set but unused.
# I0717 11:22:47.916974 104 backend_model.cc:303] model configuration:
# {
#     "name": "conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming",
#     "platform": "",
#     "backend": "riva_asr_decoder",
#     "version_policy": {
#         "latest": {
#             "num_versions": 1
#         }
#     },
#     "max_batch_size": 1024,
#     "input": [
#         {
#             "name": "CLASS_LOGITS",
#             "data_type": "TYPE_FP32",
# ...
# I0717 11:23:22.779278 104 model_lifecycle.cc:693] successfully loaded 'conformer-en-US-asr-streaming' version 1
# I0717 11:23:22.779511 104 model_lifecycle.cc:693] successfully loaded 'conformer-es-US-asr-streaming' version 1
# I0717 11:23:22.779576 104 model_lifecycle.cc:693] successfully loaded 'riva_intent_weather' version 1
# I0717 11:23:22.779697 104 server.cc:563]
# +------------------+------+
# | Repository Agent | Path |
# +------------------+------+
# +------------------+------+
#
# I0717 11:23:22.779839 104 server.cc:590]
# +----------------------+-----------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Backend              | Path                                                                              | Config                                                                                                                                                         |
# +----------------------+-----------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | riva_asr_decoder     | /opt/tritonserver/backends/riva_asr_decoder/libtriton_riva_asr_decoder.so         | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | tensorrt             | /opt/tritonserver/backends/tensorrt/libtriton_tensorrt.so                         | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_nlp_detokenizer | /opt/tritonserver/backends/riva_nlp_detokenizer/libtriton_riva_nlp_detokenizer.so | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_asr_endpointing | /opt/tritonserver/backends/riva_asr_endpointing/libtriton_riva_asr_endpointing.so | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_nlp_seqlabel    | /opt/tritonserver/backends/riva_nlp_seqlabel/libtriton_riva_nlp_seqlabel.so       | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_nlp_tokenizer   | /opt/tritonserver/backends/riva_nlp_tokenizer/libtriton_riva_nlp_tokenizer.so     | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_asr_features    | /opt/tritonserver/backends/riva_asr_features/libtriton_riva_asr_features.so       | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# | riva_nlp_pipeline    | /opt/tritonserver/backends/riva_nlp_pipeline/libtriton_riva_nlp_pipeline.so       | {"cmdline":{"auto-complete-config":"false","min-compute-capability":"6.000000","backend-directory":"/opt/tritonserver/backends","default-max-batch-size":"4"}} |
# +----------------------+-----------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# I0717 11:23:22.780086 104 server.cc:633]
# +-------------------------------------------------------------------+---------+--------+
# | Model                                                             | Version | Status |
# +-------------------------------------------------------------------+---------+--------+
# | conformer-en-US-asr-offline                                       | 1       | READY  |
# | conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline     | 1       | READY  |
# | conformer-en-US-asr-offline-endpointing-streaming-offline         | 1       | READY  |
# | conformer-en-US-asr-offline-feature-extractor-streaming-offline   | 1       | READY  |
# | conformer-en-US-asr-streaming                                     | 1       | READY  |
# | conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming           | 1       | READY  |
# | conformer-en-US-asr-streaming-endpointing-streaming               | 1       | READY  |
# | conformer-en-US-asr-streaming-feature-extractor-streaming         | 1       | READY  |
# | conformer-es-US-asr-offline                                       | 1       | READY  |
# | conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline     | 1       | READY  |
# | conformer-es-US-asr-offline-endpointing-streaming-offline         | 1       | READY  |
# | conformer-es-US-asr-offline-feature-extractor-streaming-offline   | 1       | READY  |
# | conformer-es-US-asr-streaming                                     | 1       | READY  |
# | conformer-es-US-asr-streaming-ctc-decoder-cpu-streaming           | 1       | READY  |
# | conformer-es-US-asr-streaming-endpointing-streaming               | 1       | READY  |
# | conformer-es-US-asr-streaming-feature-extractor-streaming         | 1       | READY  |
# | intent_slot_detokenizer                                           | 1       | READY  |
# | intent_slot_label_tokens_weather                                  | 1       | READY  |
# | intent_slot_tokenizer-en-US-weather                               | 1       | READY  |
# | riva-punctuation-en-US                                            | 1       | READY  |
# | riva-punctuation-es-US                                            | 1       | READY  |
# | riva-trt-conformer-en-US-asr-offline-am-streaming-offline         | 1       | READY  |
# | riva-trt-conformer-en-US-asr-streaming-am-streaming               | 1       | READY  |
# | riva-trt-conformer-es-US-asr-offline-am-streaming-offline         | 1       | READY  |
# | riva-trt-conformer-es-US-asr-streaming-am-streaming               | 1       | READY  |
# | riva-trt-riva-punctuation-en-US-nn-bert-base-uncased              | 1       | READY  |
# | riva-trt-riva-punctuation-es-US-nn-bert-base-multilingual-uncased | 1       | READY  |
# | riva-trt-riva_intent_weather-nn-bert-base-uncased                 | 1       | READY  |
# | riva-trt-riva_ner-nn-bert-base-uncased                            | 1       | READY  |
# | riva_intent_weather                                               | 1       | READY  |
# | riva_ner                                                          | 1       | READY  |
# | token_classification_detokenizer                                  | 1       | READY  |
# | token_classification_label_tokens                                 | 1       | READY  |
# | token_classification_tokenizer-en-US                              | 1       | READY  |
# +-------------------------------------------------------------------+---------+--------+
#
# I0717 11:23:22.798108 104 metrics.cc:864] Collecting metrics for GPU 0: NVIDIA A10G
# I0717 11:23:22.798367 104 metrics.cc:757] Collecting CPU metrics
# I0717 11:23:22.798537 104 tritonserver.cc:2264]
# +----------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Option                           | Value                                                                                                                                                                                                |
# +----------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | server_id                        | triton                                                                                                                                                                                               |
# | server_version                   | 2.27.0                                                                                                                                                                                               |
# | server_extensions                | classification sequence model_repository model_repository(unload_dependents) schedule_policy model_configuration system_shared_memory cuda_shared_memory binary_tensor_data statistics trace logging |
# | model_repository_path[0]         | /data/models                                                                                                                                                                                         |
# | model_control_mode               | MODE_NONE                                                                                                                                                                                            |
# | strict_model_config              | 1                                                                                                                                                                                                    |
# | rate_limit                       | OFF                                                                                                                                                                                                  |
# | pinned_memory_pool_byte_size     | 268435456                                                                                                                                                                                            |
# | cuda_memory_pool_byte_size{0}    | 1000000000                                                                                                                                                                                           |
# | response_cache_byte_size         | 0                                                                                                                                                                                                    |
# | min_supported_compute_capability | 6.0                                                                                                                                                                                                  |
# | strict_readiness                 | 1                                                                                                                                                                                                    |
# | exit_timeout                     | 30                                                                                                                                                                                                   |
# +----------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# I0717 11:23:22.800363 104 grpc_server.cc:4819] Started GRPCInferenceService at 0.0.0.0:8001
# I0717 11:23:22.800589 104 http_server.cc:3474] Started HTTPService at 0.0.0.0:8000
# I0717 11:23:22.841614 104 http_server.cc:181] Started Metrics Service at 0.0.0.0:8002
#   > Triton server is ready...
# I0717 11:23:23.592276   445 riva_server.cc:125] Using Insecure Server Credentials
# I0717 11:23:23.620163   445 model_registry.cc:120] Successfully registered: conformer-en-US-asr-offline for ASR
# I0717 11:23:23.624069   445 model_registry.cc:120] Successfully registered: conformer-en-US-asr-streaming for ASR
# I0717 11:23:23.627944   445 model_registry.cc:120] Successfully registered: conformer-es-US-asr-offline for ASR
# I0717 11:23:23.631706   445 model_registry.cc:120] Successfully registered: conformer-es-US-asr-streaming for ASR
# I0717 11:23:23.694716   445 model_registry.cc:120] Successfully registered: riva-punctuation-en-US for NLP
# I0717 11:23:23.695701   445 model_registry.cc:120] Successfully registered: riva-punctuation-es-US for NLP
# I0717 11:23:23.702648   445 model_registry.cc:120] Successfully registered: riva_intent_weather for NLP
# I0717 11:23:23.703445   445 model_registry.cc:120] Successfully registered: riva_ner for NLP
# W0717 11:23:23.874111   445 normalize.cc:52] Speech Class far file missing:/data/models/conformer-es-US-asr-offline/1/speech_class.far
# W0717 11:23:23.971728   445 normalize.cc:52] Speech Class far file missing:/data/models/conformer-es-US-asr-streaming/1/speech_class.far
# I0717 11:23:24.109943   445 model_registry.cc:120] Successfully registered: riva-punctuation-en-US for NLP
# I0717 11:23:24.110755   445 model_registry.cc:120] Successfully registered: riva-punctuation-es-US for NLP
# I0717 11:23:24.116634   445 model_registry.cc:120] Successfully registered: riva_intent_weather for NLP
# I0717 11:23:24.117362   445 model_registry.cc:120] Successfully registered: riva_ner for NLP
# I0717 11:23:24.172644   445 riva_server.cc:171] Riva Conversational AI Server listening on 0.0.0.0:50051
# W0717 11:23:24.172660   445 stats_reporter.cc:41] No API key provided. Stats reporting disabled.
# I0717 11:24:04.066844   467 grpc_riva_tts.cc:300] TTSService.Synthesize called.
# E0717 11:24:04.067051   467 grpc_riva_tts.cc:322] Unavailable model requested: Voice English-US for language en-US not found. Please specify the voice name in your SynthesizeSpeechRequest.
# I0717 11:28:02.097908   467 grpc_riva_tts.cc:300] TTSService.Synthesize called.
# E0717 11:28:02.098208   467 grpc_riva_tts.cc:322] Unavailable model requested: Voice English-US for language en-US not found. Please specify the voice name in your SynthesizeSpeechRequest.
# I0717 11:28:46.574673   452 grpc_riva_tts.cc:300] TTSService.Synthesize called.
# E0717 11:28:46.574977   452 grpc_riva_tts.cc:322] Unavailable model requested: Voice English-US for language en-US not found. Please specify the voice name in your SynthesizeSpeechRequest.
# I0717 11:28:53.865299   452 grpc_riva_tts.cc:300] TTSService.Synthesize called.
# E0717 11:28:53.865445   452 grpc_riva_tts.cc:322] Unavailable model requested: Voice English-US for language en-US not found. Please specify the voice name in your SynthesizeSpeechRequest.
# I0717 11:29:03.185285   452 grpc_riva_tts.cc:300] TTSService.Synthesize called.
# E0717 11:29:03.185427   452 grpc_riva_tts.cc:322] Unavailable model requested: Voice English-US for language en-US not found. Please specify the voice name in your SynthesizeSpeechRequest.
# I0717 11:32:49.466764   467 grpc_riva_tts.cc:300] TTSService.Synthesize called.
# E0717 11:32:49.466907   467 grpc_riva_tts.cc:322] Unavailable model requested: Voice English-US for language en-US not found. Please specify the voice name in your SynthesizeSpeechRequest.
# I0717 11:35:13.213670   452 grpc_riva_tts.cc:300] TTSService.Synthesize called.
# E0717 11:35:13.213812   452 grpc_riva_tts.cc:322] Unavailable model requested: Voice English-US for language en-US not found. Please specify the voice name in your SynthesizeSpeechRequest.
# I0717 11:35:42.058741   452 grpc_riva_tts.cc:300] TTSService.Synthesize called.
# E0717 11:35:42.058881   452 grpc_riva_tts.cc:322] Unavailable model requested: Voice  for language en-US not found. Please specify the voice name in your SynthesizeSpeechRequest.
# I0717 11:56:45.096532   467 grpc_riva_tts.cc:300] TTSService.Synthesize called.
# E0717 11:56:45.096664   467 grpc_riva_tts.cc:322] Unavailable model requested: Voice English-US for language en-US not found. Please specify the voice name in your SynthesizeSpeechRequest.

# %% [markdown]
# ---
# # 7.2 Riva TTS Service Request
# To access the Riva API, we need to:
# 1. Start the Riva Speech Skills server. (already done!)
# 2. Install the [Riva Client library](https://github.com/nvidia-riva/tutorials#running-the-riva-client). (already done for this course!)
# 3. Set up requests using the [documentation tutorial example](https://docs.nvidia.com/deeplearning/riva/user-guide/docs/tutorials/tts-basics-customize-ssml.html#customizing-riva-tts-audio-output-with-ssml) for transcription.

# %% [markdown]
# ## 7.2.1 Python Client Demo
#
# Riva TTS supports a number of options while making a text-to-speech request to the gRPC endpoint, as shown above. Let’s learn more about these parameters:
#
# - `language_code`: Language of the generated audio. en-US represents English (US) and is currently the only language supported OOTB.
# - `encoding` - Type of audio encoding to generate. Currently, only LINEAR_PCM is supported.
# - `sample_rate_hz` - Sample rate of the generated audio. Depends on the microphone and is usually 22khz or 44khz.
# - `voice_name` - Voice used to synthesize the audio. Currently, Riva offers two OOTB voices (English-US.Female-1, English-US.Male-1).

# %%
import numpy as np
import IPython.display as ipd
import riva.client

# %% [markdown]
# Now that everything is set up, let's give an input that we want our models to speak

# %%
sample_rate_hz = 44100

def remove_braces(braced_text):
    return braced_text.replace("{@","").replace("}","")

def tts_predict(text):
    auth = riva.client.Auth(uri='localhost:50051')
    riva_tts = riva.client.SpeechSynthesisService(auth)
    req = { 
            "language_code"  : "en-US",
            "encoding"       : riva.client.AudioEncoding.LINEAR_PCM ,   # Currently only LINEAR_PCM is supported
            "sample_rate_hz" : sample_rate_hz,                          # Generate 44.1KHz audio
            "voice_name"     : "English-US.Female-1"                    # The name of the voice to generate
    }
    req["text"] = text
    resp = riva_tts.synthesize(**req)
    audio_samples = np.frombuffer(resp.audio, dtype=np.int16)
    return audio_samples, remove_braces(resp.meta.processed_text)

# %%
audio_samples, processed_text =tts_predict("Hi, my name is Dana and I work for NVIDIA.")
print(remove_braces(processed_text))
ipd.Audio(audio_samples, rate=sample_rate_hz)
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 audio_samples, processed_text =tts_predict("Hi, my name is Dana and I work for NVIDIA.")
#       2 print(remove_braces(processed_text))
#       3 ipd.Audio(audio_samples, rate=sample_rate_hz)
#
# Cell In [10], line 16, in tts_predict(text)
#       9 req = {
#      10         "language_code"  : "en-US",
#      11         "encoding"       : riva.client.AudioEncoding.LINEAR_PCM ,   # Currently only LINEAR_PCM is supported
#      12         "sample_rate_hz" : sample_rate_hz,                          # Generate 44.1KHz audio
#      13         "voice_name"     : "English-US.Female-1"                    # The name of the voice to generate
#      14 }
#      15 req["text"] = text
# ---> 16 resp = riva_tts.synthesize(**req)
#      17 audio_samples = np.frombuffer(resp.audio, dtype=np.int16)
#      18 return audio_samples, remove_braces(resp.meta.processed_text)
#
# File /opt/conda/lib/python3.8/site-packages/riva/client/tts.py:68, in SpeechSynthesisService.synthesize(self, text, voice_name, language_code, encoding, sample_rate_hz, future)
#      66     req.voice_name = voice_name
#      67 func = self.stub.Synthesize.future if future else self.stub.Synthesize
# ---> 68 return func(req, metadata=self.auth.get_auth_metadata())
#
# File /opt/conda/lib/python3.8/site-packages/grpc/_channel.py:1030, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1021 def __call__(self,
#    1022              request: Any,
#    1023              timeout: Optional[float] = None,
#    (...)
#    1026              wait_for_ready: Optional[bool] = None,
#    1027              compression: Optional[grpc.Compression] = None) -> Any:
#    1028     state, call, = self._blocking(request, timeout, metadata, credentials,
#    1029                                   wait_for_ready, compression)
# -> 1030     return _end_unary_response_blocking(state, call, False, None)
#
# File /opt/conda/lib/python3.8/site-packages/grpc/_channel.py:910, in _end_unary_response_blocking(state, call, with_call, deadline)
#     908         return state.response
#     909 else:
# --> 910     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.INVALID_ARGUMENT
# 	details = "Model is not available on server: Voice English-US for language en-US not found. Please specify the voice name in your SynthesizeSpeechRequest."
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"Model is not available on server: Voice English-US for language en-US not found. Please specify the voice name in your SynthesizeSpeechRequest.", grpc_status:3, created_time:"2025-07-17T12:07:33.211830173+00:00"}"
# >

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE                                   COMMAND                  CREATED       STATUS       PORTS                                                                                                 NAMES
# 7b87d3ebc7c9   nvcr.io/nvidia/riva/riva-speech:2.8.1   "/opt/nvidia/nvidia_…"   2 hours ago   Up 2 hours   0.0.0.0:50051->50051/tcp, 0.0.0.0:32770->8000/tcp, 0.0.0.0:32769->8001/tcp, 0.0.0.0:32768->8002/tcp   riva-speech

# %%
# !bash dli_workspace/riva_quickstart/config.sh \
  --deploy_nlp=false \
  --deploy_asr=false \
  --deploy_tts=true

# %% [markdown]
# ## 7.2.2 Customizing TTS
#
# The Speech Synthesis Markup Language (SSML) specification is a markup for directing the performance of the virtual speaker. Riva supports portions of SSML, allowing you to adjust pitch, rate, and pronunciation of the generated audio. SSML support is available only for the FastPitch model at this time. th a different root tag are treated as raw input text.
#
# Riva TTS supports the following SSML tags:
# - The prosody tag, which supports attributes rate, pitch, and volume, through which we can control the rate, pitch, and volume of the generated audio.
# - The phoneme tag, which allows us to control the pronunciation of the generated audio.
# - The sub tag, which allows us to replace the pronunciation of the specified word or phrase with a different word or phrase.
#
# Let's look at [customization of Riva TTS with these SSML tags](https://docs.nvidia.com/deeplearning/riva/user-guide/docs/tutorials/tts-basics-customize-ssml.html#customizing-riva-tts-audio-output-with-ssml) in some detail.

# %%
# prosody tag example
text='<speak><prosody pitch="0.1" rate="100%">NVIDIA</prosody></speak>'
audio_samples, processed_text = tts_predict(text)
print("preprocessed text: ", processed_text)
ipd.Audio(audio_samples, rate=sample_rate_hz)

# %% [markdown]
# To fix the pronunciation, you can use the phoneme tag.  A list of the TTS phones supported in Riva can be found [here](https://docs.nvidia.com/deeplearning/riva/user-guide/docs/tts/tts-phones.html).

# %%
# prosody tag and phoneme tag example
text='<speak><prosody pitch="0.1" rate="100%"><phoneme ph="ɛnˈvɪdiə">NVIDIA</phoneme></prosody></speak>'
audio_samples, processed_text = tts_predict(text)
print("preprocessed text: ", processed_text)
ipd.Audio(audio_samples, rate=sample_rate_hz)

# %%
# prosody tag and phoneme tag example
text='<speak><prosody pitch="0.1" rate="100%">Hi, my name is Dana and I work for <phoneme ph="ɛnˈvɪdiə">NVIDIA</phoneme>.</prosody></speak>'
audio_samples, processed_text = tts_predict(text)
print("preprocessed text: ", processed_text)
ipd.Audio(audio_samples, rate=sample_rate_hz)

# %% [markdown]
# ## 7.2.3 Exercise: Customize Phonemes
# Let's revisit the pronunciation we worked on in the NeMo notebook.

# %%
audio_samples, processed_text =tts_predict("His name is Adam Grzywaczewski and he works for NVIDIA.")
print(remove_braces(processed_text))
ipd.Audio(audio_samples, rate=sample_rate_hz)

# %% [markdown]
# The pronunciations for "Grzywaczewski" and "NVIDIA" were not correct. Change those pronunciations to "ɡzɪvɑˈtʃɛvski" and "ɛnˈvɪdiə" using SSML tags.<br>
# If you get stuck, you can check the [solution](solutions/ex7.2.3.ipynb).

# %%
text=#FIXME
audio_samples, processed_text = tts_predict(text)
print("preprocessed text: ", processed_text)
ipd.Audio(audio_samples, rate=sample_rate_hz)

# %% [markdown]
# ---
# # 7.3 Stop Riva Services
# We need to stop Riva services as we will be modifying the deployed models.

# %%
# Run Riva Stop. 
# !bash $RIVA_QS/riva_stop.sh

# %% [markdown]
# ---
# # 7.4 Shut Down the Kernel
# <h3 style="color:red;">Important!</h3>
#
# From the menu above, choose ***Kernel->Shut Down Kernel*** to fully clear GPU memory before moving on.

# %% [markdown]
# ---
# <h2 style="color:green;">Congratulations!</h2>
#
# In this notebook, you have:
# - Launched Riva TTS service
# - Requested the TTS service using a Python client API
# - Customized pronunciations
#
# In the nex notebook you'll "put it all together" to deploy a [Full Pipline](008_Full_Pipeline.ipynb).

# %% [markdown]
# <a href="https://www.nvidia.com/dli"> <img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/> </a>
