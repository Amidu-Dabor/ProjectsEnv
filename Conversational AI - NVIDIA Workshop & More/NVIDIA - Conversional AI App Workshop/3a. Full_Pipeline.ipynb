# %% [markdown]
# <a href="https://www.nvidia.com/dli"> <img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/> </a>

# %% [markdown]
# # 8.0 ASR-NLP-TTS Deployment
# ## (part of Lab 2)

# %% [markdown]
# In this notebook, you'll deploy a full pipeline with [NVIDIA Riva](https://developer.nvidia.com/riva). After building a "plain vanilla" end-to-end application using out-of-the-box models, you'll customize the pipeline for a specific restaurant use case, including a large language model (LLM) API endpoint as a dialog manager.
#
# **[8.1 Full Pipeline With OOTB Models](#8.1-Full-Pipeline-With-OOTB-Models)<br>**
# &nbsp;&nbsp;&nbsp;&nbsp;[8.1.1 Model Deployment](#8.1.1-Model-Deployment)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[8.1.2 Excercise: Riva Configuration](#8.1.2-Excercise:-Riva-Configuration)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[8.1.3 Riva Start Services](#8.1.3-Riva-Start-Services)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[8.1.4 OOTB Pipeline Demo](#8.1.4-OOTB-Pipeline-Demo)<br>
# **[8.2 ASR Customization](#8.2-ASR-Customization)<br>**
# &nbsp;&nbsp;&nbsp;&nbsp;[8.2.1 Word Boosting](#8.2.1-Word-Boosting)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[8.2.2 Exercise: Negative Word Boost](#8.2.2-Exercise:-Negative-Word-Boost)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[8.2.3 Lexicon Customization](#8.2.3-Lexicon-Customization)<br>
# **[8.3 Dialog Manager](#8.3-Dialog-Manager)<br>**
# &nbsp;&nbsp;&nbsp;&nbsp;[8.3.1 API Endpoint Keys](#8.3.1-API-Endpoint-Keys)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[8.3.2 Using LangChain With Llama 3](#8.3.2-Using-LangChain-With-Llama-3)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[8.3.3 Restaurant Menu Prompt](#8.3.3-Restaurant-Menu-Prompt)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[8.3.4 Exercise: Changing the Prompt](#8.3.4-Exercise:-Changing-the-Prompt)<br>
# **[8.4 TTS Customization](#8.4-TTS-Customization)<br>**
# **[8.5 Customized Restaurant Pipeline Demo](#8.5-Customized-Restaurant-Pipeline-Demo)<br>**
# &nbsp;&nbsp;&nbsp;&nbsp;[8.5.1 Exercise: Run a Custom Pipeline](#8.5.1-Exercise:-Run-a-Custom-Pipeline)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[8.5.2 Shut Down Riva](#8.5.2-Shut-Down-Riva)<br>
# **[8.6 Shut Down the Kernel](#8.6-Shut-Down-the-Kernel)<br>**

# %% [markdown]
# ### Notebook Dependencies
# The steps in this notebook assume that you have:
#
# 1. **NGC Credentials**<br>Be sure you have added your NGC credential as described in the [NGC Setup notebook](003_Intro_NGC_Setup.ipynb)

# %% [markdown]
# ---
# # 8.1 Full Pipeline With OOTB Models
#
# In previous notebooks, we took a close look at ASR and TTS speech models.  In this notebook, we'll (optionally) add NLP (Natural Language Processing) models and LLM (Large Language Models) to build a full pipeline. NLP models interpret text in various ways so that action can be taken based on the text's meaning. LLM models extend this capability by leveraging vast amounts of data and complex architectures to understand and generate human-like text.
# We'll use the standard OOTB (out-of-the-box) models that Riva pulls from NGC.

# %% [markdown]
# ## 8.1.1 Model Deployment
# The default ASR and TTS service models were deployed earlier in their own model repositories, `/dli_workspace/riva-asr-model-repo` and `/dli_workspace/riva-tts-model-repo`.  For the full pipeline, we'll need to deploy default models for ASR, TTS and NLP services (the LLM will be deployed with LangChain). The `riva_init.sh` command loads and builds models specific to the GPU you are using, but to save time for this course, these have been preloaded.
#
# The optimized NLP models are already located in the `/dli_workspace/riva-full-model-repo`, but lets go ahead and copy the ASR and TTS models there as well to save some build time:

# %%
# Set the Riva Quick Start directory
WORKSPACE='/dli_workspace'
RIVA_QS = WORKSPACE + "/riva_quickstart"
RIVA_MODEL_REPO = WORKSPACE + "/riva-full-model-repo"
# !mkdir -p $RIVA_MODEL_REPO

# %%
# %%bash
# # Copy all the ASR and TTS models for convenience (faster deployment)
# # Time is about 1-2 minutes for the copy
# cp -rn  /dli_workspace/riva-asr-model-repo/* \
#     /dli_workspace/riva-full-model-repo/
# cp -rn  /dli_workspace/riva-tts-model-repo/* \
#     /dli_workspace/riva-full-model-repo/

# %%
# check to see what models are there now
# !ls $RIVA_MODEL_REPO/models
# Out:
# conformer-en-US-asr-offline
# conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline
# conformer-en-US-asr-offline-endpointing-streaming-offline
# conformer-en-US-asr-offline-feature-extractor-streaming-offline
# conformer-en-US-asr-streaming
# conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming
# conformer-en-US-asr-streaming-endpointing-streaming
# conformer-en-US-asr-streaming-feature-extractor-streaming
# conformer-es-US-asr-offline
# conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline
# conformer-es-US-asr-offline-endpointing-streaming-offline
# conformer-es-US-asr-offline-feature-extractor-streaming-offline
# conformer-es-US-asr-streaming
# conformer-es-US-asr-streaming-ctc-decoder-cpu-streaming
# conformer-es-US-asr-streaming-endpointing-streaming
# conformer-es-US-asr-streaming-feature-extractor-streaming
# fastpitch_hifigan_ensemble-English-US
# intent_slot_detokenizer
# intent_slot_label_tokens_weather
# intent_slot_tokenizer-en-US-weather
# qa_qa_postprocessor
# qa_tokenizer-en-US
# riva-onnx-fastpitch_encoder-English-US
# riva-punctuation-en-US
# riva-punctuation-es-US
# riva-trt-conformer-en-US-asr-offline-am-streaming-offline
# riva-trt-conformer-en-US-asr-streaming-am-streaming
# riva-trt-conformer-es-US-asr-offline-am-streaming-offline
# riva-trt-conformer-es-US-asr-streaming-am-streaming
# riva-trt-hifigan-English-US
# riva-trt-riva-punctuation-en-US-nn-bert-base-uncased
# riva-trt-riva-punctuation-es-US-nn-bert-base-multilingual-uncased
# riva-trt-riva_intent_weather-nn-bert-base-uncased
# riva-trt-riva_ner-nn-bert-base-uncased
# riva-trt-riva_qa-nn-bert-base-uncased
# riva-trt-riva_text_classification_domain-nn-bert-base-uncased
# riva_intent_weather
# riva_ner
# riva_qa
# riva_text_classification_domain
# spectrogram_chunker-English-US
# text_classification_tokenizer-en-US-domain
# token_classification_detokenizer
# token_classification_label_tokens
# token_classification_tokenizer-en-US
# tts_postprocessor-English-US
# tts_preprocessor-English-US

# %% [markdown]
# ## 8.1.2 Exercise: Riva Configuration
#
# Open [config.sh](dli_workspace/riva_quickstart/config.sh) and modify it to deploy all three services (ASR, NLP, TTS) using the `/dli_workspace/riva-full-model-repo` location that we've preloaded with all the models.  Save your work.
#
# If you're not sure what to change, take a peek at the [solution](solutions/ex8.1.2_config.sh).

# %% [markdown]
# Check your work.  The `diff` comparison in the following cell should have no output.

# %%
# Check your work
# !diff solutions/ex8.1.2_config.sh dli_workspace/riva_quickstart/config.sh

# %%
# Quick fix!
# !cp solutions/ex8.1.2_config.sh dli_workspace/riva_quickstart/config.sh

# %% [markdown]
# ## 8.1.3 Riva Start Services
#
# The `riva_init.sh` script downloads the Riva containers needed, downloads models listed in `config.sh`, and optimizes  models as required with [NVIDIA TensorRT](https://developer.nvidia.com/tensorrt). Since we've already downloaded the containers and preloaded the optimized models, `riva_init.sh` won't have much to do, but it is provided here for completeness.
#
# The `riva_start.sh` script starts the server.

# %%
# Initialize Riva 
# !cd $RIVA_QS && bash riva_init.sh config.sh
# Out:
# Logging into NGC docker registry if necessary...
# Pulling required docker images if necessary...
# Note: This may take some time, depending on the speed of your Internet connection.
# > Pulling Riva Speech Server images.
#   > Image nvcr.io/nvidia/riva/riva-speech:2.8.1 exists. Skipping.
#   > Image nvcr.io/nvidia/riva/riva-speech:2.8.1-servicemaker exists. Skipping.
#
# Downloading models (RMIRs) from NGC...
# Note: this may take some time, depending on the speed of your Internet connection.
# To skip this process and use existing RMIRs set the location and corresponding flag in config.sh.
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
#
# ==========================
# === Riva Speech Skills ===
# ==========================
#
# NVIDIA Release  (build 49655095)
# Copyright (c) 2016-2022, NVIDIA CORPORATION & AFFILIATES. All rights reserved.
#
# Copyright (c) 2018-2022, NVIDIA CORPORATION & AFFILIATES. All rights reserved.
#
# https://developer.nvidia.com/tensorrt
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the NVIDIA Deep Learning Container License.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/ngc/nvidia-deep-learning-container-license
#
# To install Python sample dependencies, run /opt/tensorrt/python/python_setup.sh
#
# To install the open-source samples corresponding to this TensorRT release version
# run /opt/tensorrt/install_opensource.sh.  To build the open source parsers,
# plugins, and samples for current top-of-tree on master or a different branch,
# run /opt/tensorrt/install_opensource.sh -b <branch>
# See https://github.com/NVIDIA/TensorRT for more information.
#
# NOTE: CUDA Forward Compatibility mode ENABLED.
#   Using CUDA 11.8 driver version 520.61.05 with kernel driver version 510.47.03.
#   See https://docs.nvidia.com/deploy/cuda-compatibility/ for details.
#
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# /data/artifacts /opt/riva
# Directory rmir_asr_conformer_en_us_str_v2.8.0 already exists, skipping. Use '--force' option to override.
# Directory rmir_asr_conformer_en_us_ofl_v2.8.0 already exists, skipping. Use '--force' option to override.
# Directory rmir_nlp_punctuation_bert_base_en_us_v2.8.0 already exists, skipping. Use '--force' option to override.
# Directory rmir_nlp_punctuation_bert_base_en_us_v2.8.0 already exists, skipping. Use '--force' option to override.
# Directory rmir_nlp_named_entity_recognition_bert_base_v2.8.0 already exists, skipping. Use '--force' option to override.
# Directory rmir_nlp_intent_slot_bert_base_v2.8.0 already exists, skipping. Use '--force' option to override.
# Directory rmir_nlp_question_answering_bert_base_v2.8.0 already exists, skipping. Use '--force' option to override.
# Directory rmir_nlp_text_classification_bert_base_v2.8.0 already exists, skipping. Use '--force' option to override.
# Directory rmir_tts_fastpitch_hifigan_en_us_ipa_v2.8.0 already exists, skipping. Use '--force' option to override.
# /opt/riva
#
# + [[ non-tegra != \t\e\g\r\a ]]
# + [[ non-tegra == \t\e\g\r\a ]]
# + echo 'Converting RMIRs at /dli_workspace/riva-full-model-repo/rmir to Riva Model repository.'
# Converting RMIRs at /dli_workspace/riva-full-model-repo/rmir to Riva Model repository.
# + docker run --init -it --rm --gpus '"device=0"' -v /dli_workspace/riva-full-model-repo:/data -e MODEL_DEPLOY_KEY=tlt_encode --name riva-service-maker --network host nvcr.io/nvidia/riva/riva-speech:2.8.1-servicemaker deploy_all_models /data/rmir /data/models
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
#
# ==========================
# === Riva Speech Skills ===
# ==========================
#
# NVIDIA Release  (build 49655095)
# Copyright (c) 2016-2022, NVIDIA CORPORATION & AFFILIATES. All rights reserved.
#
# Copyright (c) 2018-2022, NVIDIA CORPORATION & AFFILIATES. All rights reserved.
#
# https://developer.nvidia.com/tensorrt
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the NVIDIA Deep Learning Container License.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/ngc/nvidia-deep-learning-container-license
#
# To install Python sample dependencies, run /opt/tensorrt/python/python_setup.sh
#
# To install the open-source samples corresponding to this TensorRT release version
# run /opt/tensorrt/install_opensource.sh.  To build the open source parsers,
# plugins, and samples for current top-of-tree on master or a different branch,
# run /opt/tensorrt/install_opensource.sh -b <branch>
# See https://github.com/NVIDIA/TensorRT for more information.
#
# NOTE: CUDA Forward Compatibility mode ENABLED.
#   Using CUDA 11.8 driver version 520.61.05 with kernel driver version 510.47.03.
#   See https://docs.nvidia.com/deploy/cuda-compatibility/ for details.
#
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# 2025-07-17 12:22:08,932 [INFO] Writing Riva model repository to '/data/models'...
# 2025-07-17 12:22:08,932 [INFO] The riva model repo target directory is /data/models
# 2025-07-17 12:22:16,316 [INFO] Using obey-precision pass with fp16 TRT
# 2025-07-17 12:22:16,317 [WARNING] /data/models/riva-trt-riva_ner-nn-bert-base-uncased already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-riva_ner-nn-bert-base-uncased
# 2025-07-17 12:22:16,317 [WARNING] /data/models/token_classification_tokenizer-en-US already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/token_classification_tokenizer-en-US
# 2025-07-17 12:22:16,317 [WARNING] /data/models/token_classification_label_tokens already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/token_classification_label_tokens
# 2025-07-17 12:22:16,317 [WARNING] /data/models/token_classification_detokenizer already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/token_classification_detokenizer
# 2025-07-17 12:22:16,317 [WARNING] /data/models/riva_ner already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_ner
# 2025-07-17 12:22:24,732 [INFO] Using obey-precision pass with fp16 TRT
# 2025-07-17 12:22:24,733 [WARNING] /data/models/riva-trt-riva_intent_weather-nn-bert-base-uncased already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-riva_intent_weather-nn-bert-base-uncased
# 2025-07-17 12:22:24,733 [WARNING] /data/models/intent_slot_tokenizer-en-US-weather already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/intent_slot_tokenizer-en-US-weather
# 2025-07-17 12:22:24,733 [WARNING] /data/models/intent_slot_label_tokens_weather already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/intent_slot_label_tokens_weather
# 2025-07-17 12:22:24,733 [WARNING] /data/models/intent_slot_detokenizer already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/intent_slot_detokenizer
# 2025-07-17 12:22:24,733 [WARNING] /data/models/riva_intent_weather already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_intent_weather
# 2025-07-17 12:22:36,985 [INFO] Using obey-precision pass with fp16 TRT
# 2025-07-17 12:22:36,985 [WARNING] /data/models/riva-trt-conformer-es-US-asr-streaming-am-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-conformer-es-US-asr-streaming-am-streaming
# 2025-07-17 12:22:36,985 [WARNING] /data/models/conformer-es-US-asr-streaming-feature-extractor-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-es-US-asr-streaming-feature-extractor-streaming
# 2025-07-17 12:22:36,985 [WARNING] /data/models/conformer-es-US-asr-streaming-endpointing-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-es-US-asr-streaming-endpointing-streaming
# 2025-07-17 12:22:36,986 [WARNING] /data/models/conformer-es-US-asr-streaming-ctc-decoder-cpu-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-es-US-asr-streaming-ctc-decoder-cpu-streaming
# 2025-07-17 12:22:36,986 [WARNING] /data/models/conformer-es-US-asr-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-es-US-asr-streaming
# 2025-07-17 12:22:49,358 [INFO] Using obey-precision pass with fp16 TRT
# 2025-07-17 12:22:49,358 [WARNING] /data/models/riva-trt-conformer-en-US-asr-offline-am-streaming-offline already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-conformer-en-US-asr-offline-am-streaming-offline
# 2025-07-17 12:22:49,358 [WARNING] /data/models/conformer-en-US-asr-offline-feature-extractor-streaming-offline already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-en-US-asr-offline-feature-extractor-streaming-offline
# 2025-07-17 12:22:49,358 [WARNING] /data/models/conformer-en-US-asr-offline-endpointing-streaming-offline already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-en-US-asr-offline-endpointing-streaming-offline
# 2025-07-17 12:22:49,358 [WARNING] /data/models/conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline
# 2025-07-17 12:22:49,359 [WARNING] /data/models/conformer-en-US-asr-offline already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-en-US-asr-offline
# 2025-07-17 12:23:08,203 [INFO] Using obey-precision pass with fp16 TRT
# 2025-07-17 12:23:08,203 [WARNING] /data/models/riva-trt-riva-punctuation-es-US-nn-bert-base-multilingual-uncased already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-riva-punctuation-es-US-nn-bert-base-multilingual-uncased
# 2025-07-17 12:23:08,203 [WARNING] /data/models/riva-punctuation-es-US already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-punctuation-es-US
# 2025-07-17 12:23:20,846 [INFO] Using obey-precision pass with fp16 TRT
# 2025-07-17 12:23:20,846 [WARNING] /data/models/riva-trt-conformer-es-US-asr-offline-am-streaming-offline already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-conformer-es-US-asr-offline-am-streaming-offline
# 2025-07-17 12:23:20,846 [WARNING] /data/models/conformer-es-US-asr-offline-feature-extractor-streaming-offline already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-es-US-asr-offline-feature-extractor-streaming-offline
# 2025-07-17 12:23:20,847 [WARNING] /data/models/conformer-es-US-asr-offline-endpointing-streaming-offline already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-es-US-asr-offline-endpointing-streaming-offline
# 2025-07-17 12:23:20,847 [WARNING] /data/models/conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-es-US-asr-offline-ctc-decoder-cpu-streaming-offline
# 2025-07-17 12:23:20,847 [WARNING] /data/models/conformer-es-US-asr-offline already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-es-US-asr-offline
# 2025-07-17 12:23:29,215 [INFO] Using obey-precision pass with fp16 TRT
# 2025-07-17 12:23:29,215 [WARNING] /data/models/riva-trt-riva_qa-nn-bert-base-uncased already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-riva_qa-nn-bert-base-uncased
# 2025-07-17 12:23:29,215 [WARNING] /data/models/qa_tokenizer-en-US already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/qa_tokenizer-en-US
# 2025-07-17 12:23:29,215 [WARNING] /data/models/qa_qa_postprocessor already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/qa_qa_postprocessor
# 2025-07-17 12:23:29,215 [WARNING] /data/models/riva_qa already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_qa
# 2025-07-17 12:23:44,229 [INFO] Using obey-precision pass with fp16 TRT
# 2025-07-17 12:23:44,229 [WARNING] /data/models/riva-trt-conformer-en-US-asr-streaming-am-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-conformer-en-US-asr-streaming-am-streaming
# 2025-07-17 12:23:44,229 [WARNING] /data/models/conformer-en-US-asr-streaming-feature-extractor-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-en-US-asr-streaming-feature-extractor-streaming
# 2025-07-17 12:23:44,229 [WARNING] /data/models/conformer-en-US-asr-streaming-endpointing-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-en-US-asr-streaming-endpointing-streaming
# 2025-07-17 12:23:44,229 [WARNING] /data/models/conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-en-US-asr-streaming-ctc-decoder-cpu-streaming
# 2025-07-17 12:23:44,229 [WARNING] /data/models/conformer-en-US-asr-streaming already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/conformer-en-US-asr-streaming
# 2025-07-17 12:23:51,552 [INFO] Using obey-precision pass with fp16 TRT
# 2025-07-17 12:23:51,552 [WARNING] /data/models/riva-trt-riva_text_classification_domain-nn-bert-base-uncased already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-riva_text_classification_domain-nn-bert-base-uncased
# 2025-07-17 12:23:51,552 [WARNING] /data/models/text_classification_tokenizer-en-US-domain already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/text_classification_tokenizer-en-US-domain
# 2025-07-17 12:23:51,552 [WARNING] /data/models/riva_text_classification_domain already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva_text_classification_domain
# 2025-07-17 12:24:03,132 [INFO] Using obey-precision pass with fp16 TRT
# 2025-07-17 12:24:03,132 [WARNING] /data/models/riva-trt-riva-punctuation-en-US-nn-bert-base-uncased already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-riva-punctuation-en-US-nn-bert-base-uncased
# 2025-07-17 12:24:03,132 [WARNING] /data/models/riva-punctuation-en-US already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-punctuation-en-US
# 2025-07-17 12:24:05,425 [INFO] Using onnx runtime
# 2025-07-17 12:24:05,425 [INFO] Using tensorrt with fp16
# 2025-07-17 12:24:05,426 [WARNING] /data/models/tts_preprocessor-English-US already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/tts_preprocessor-English-US
# 2025-07-17 12:24:05,426 [WARNING] /data/models/riva-onnx-fastpitch_encoder-English-US already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-onnx-fastpitch_encoder-English-US
# 2025-07-17 12:24:05,426 [WARNING] /data/models/spectrogram_chunker-English-US already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/spectrogram_chunker-English-US
# 2025-07-17 12:24:05,426 [WARNING] /data/models/riva-trt-hifigan-English-US already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/riva-trt-hifigan-English-US
# 2025-07-17 12:24:05,426 [WARNING] /data/models/tts_postprocessor-English-US already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/tts_postprocessor-English-US
# 2025-07-17 12:24:05,426 [WARNING] /data/models/fastpitch_hifigan_ensemble-English-US already exists, skipping deployment.  To force deployment rerun with -f or remove the /data/models/fastpitch_hifigan_ensemble-English-US
# + '[' 0 -ne 0 ']'
# + [[ non-tegra == \t\e\g\r\a ]]
# + echo
#
# + echo 'Riva initialization complete. Run ./riva_start.sh to launch services.'
# Riva initialization complete. Run ./riva_start.sh to launch services.

# %%
# Start the Riva server (about 1 minute)
# !cd $RIVA_QS && bash riva_start.sh config.sh
# Out:
# Riva Speech already running. Skipping...
# Riva server is ready...

# %% [markdown]
# ## 8.1.4 OOTB Pipeline Demo
# Now that we have the Riva server running with all the OOTB models, let's build an application that will:
#
# 1. Transcribe audio into text (ASR)
# 2. Find a name in the text (NER)
# 3. Determine what text to output in response (DM)
# 4. Output audio of the text response (TTS)
#
# <img src="images/pipeline/full_pipeline_ootb.png">
#
# We've already explored how ASR (step 1) and TTS (step 4) work, but now we add a Named Entity Recognition (NER) model and a Dialog Manager (DM) to the pipeline.
#
# NER is a Natural Language Processing (NLP) task. NER, also referred to as entity chunking, identification, or extraction, is the task of detecting and classifying key information (entities) in text. In other words, a NER model takes a piece of text as input and for each word in the text, the model identifies a category the word belongs to. For example, in a sentence: "Mary lives in Santa Clara and works at NVIDIA", the NER model should detect that Mary is a person, Santa Clara is a location and NVIDIA is a company.
#
# The DM is responsible for keeping track of the conversation state and determining responses. In this short example, the DM is a very basic string interpreter that returns a pre-defined response, based on the NER results. Later on in this notebook, this will be replaced by a chat completion LLM (LLama 3) to create prompted responses to the queries, making the use of NER unnecessary.

# %% [markdown]
# Begin by importing the Riva client and some other useful libraries.

# %%
import riva.client
import numpy as np
import IPython.display as ipd
import io
import time
import librosa

# %% [markdown]
# **Step 1: ASR**
#
# Create an ASR function to transcribe audio to text. Then give it a try using a simple sentence.

# %%
# Define a Python function to transcribe text from audio
def asr_predict(SAMPLE):
    auth = riva.client.Auth(uri='localhost:50051')
    riva_asr = riva.client.ASRService(auth)
    # This example uses a .wav file with LINEAR_PCM encoding.
    # read in an audio file from local disk
    # Set up an offline/batch recognition request
    config = riva.client.RecognitionConfig()
    config.language_code = "en-US"                    # Language code of the audio clip
    config.max_alternatives = 1                       # How many top-N hypotheses to return
    config.enable_automatic_punctuation = True        # Add punctuation when end of VAD detected
    config.audio_channel_count = 1     
    with io.open(SAMPLE, 'rb') as fh:
        content = fh.read()
    response = riva_asr.offline_recognize(content, config)
    transcript=response.results[0].alternatives[0].transcript
    return transcript

# %%
SAMPLE="/dli_workspace/data/audio_sample_resampled2.wav"

with io.open(SAMPLE, 'rb') as fh:
    content = fh.read()
ipd.Audio(SAMPLE, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
transcript=asr_predict(SAMPLE)
print("ASR Transcript:", transcript)
# Out:
# ASR Transcript: Hi, my name is Dana and I Work for NVIDIA.

# %% [markdown]
# **Step 2: NER**
#
# Create an NER function to find special words, such as persons, locations, and organizations, within the transcribed text.  For the sentence "Hi, my name is Dana and I work for NVIDIA", the NER model should recognize "Dana" as a name and "NVIDIA" as an organization.

# %%
# Define a Python function to extract entities from text
def ner_predict(text):
    auth = riva.client.Auth(uri='localhost:50051')
    service = riva.client.NLPService(auth)
    tokens, slots, slot_confidences, starts, ends = riva.client.extract_most_probable_token_classification_predictions(
        service.classify_tokens(input_strings=text, model_name='riva_ner'))
    return tokens[0],slots[0]

# %%
tokens,slots=ner_predict(transcript)
print(tokens)
print(slots)
# Out:
# ['dana', 'nvidia']
# ['PER', 'ORG']

# %% [markdown]
# **Step 3: DM**
#
# For demonstration purposes, we'll build a very basic dialog manager that just looks for a person's name in the sentence and uses that name in the response text (if it exists). In a later section, we will use an LLM for the dialog.

# %%
# Dialog Manager
def dm_predict(slots, tokens):
    if "PER" in slots:
        index = slots.index("PER")
        response="Hi " + tokens[index] + ", how can I help you?"
    else:
        response="Hi, how can I help you?"
    return response

# %%
response = dm_predict(slots, tokens)
print(response)
# Out:
# Hi dana, how can I help you?

# %% [markdown]
# **Step 4: TTS**
#
# Finally, we'll use the TTS model to output the response sentence as audio.

# %%
sample_rate_hz = 44100

# helper function for more readable output
def remove_braces(braced_text):
    return braced_text.replace("{@","").replace("}","")

# Define a Python function to create speech from text
def tts_predict(text):
    auth = riva.client.Auth(uri='localhost:50051')
    riva_tts = riva.client.SpeechSynthesisService(auth)
    req = { 
            "language_code"  : "en-US",
            "encoding"       : riva.client.AudioEncoding.LINEAR_PCM ,   # Currently only LINEAR_PCM is supported
            "sample_rate_hz" : sample_rate_hz,                          # Generate 44.1KHz audio
            "voice_name"     : "English-US.Female-1"                    # The name of the voice to generate
    }
    req["text"] = text
    resp = riva_tts.synthesize(**req)
    audio_samples = np.frombuffer(resp.audio, dtype=np.int16)
    return audio_samples, remove_braces(resp.meta.processed_text)

# %%
audio_samples, processed_text =tts_predict(response)
print(processed_text)
ipd.Audio(audio_samples, rate=sample_rate_hz, autoplay=True)
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# Cell In [23], line 1
# ----> 1 audio_samples, processed_text =tts_predict(response)
#       2 print(processed_text)
#       3 ipd.Audio(audio_samples, rate=sample_rate_hz, autoplay=True)
#
# Cell In [22], line 18, in tts_predict(text)
#      11 req = {
#      12         "language_code"  : "en-US",
#      13         "encoding"       : riva.client.AudioEncoding.LINEAR_PCM ,   # Currently only LINEAR_PCM is supported
#      14         "sample_rate_hz" : sample_rate_hz,                          # Generate 44.1KHz audio
#      15         "voice_name"     : "English-US.Male-1"                    # The name of the voice to generate
#      16 }
#      17 req["text"] = text
# ---> 18 resp = riva_tts.synthesize(**req)
#      19 audio_samples = np.frombuffer(resp.audio, dtype=np.int16)
#      20 return audio_samples, remove_braces(resp.meta.processed_text)
#
# File /opt/conda/lib/python3.8/site-packages/riva/client/tts.py:68, in SpeechSynthesisService.synthesize(self, text, voice_name, language_code, encoding, sample_rate_hz, future)
#      66     req.voice_name = voice_name
#      67 func = self.stub.Synthesize.future if future else self.stub.Synthesize
# ---> 68 return func(req, metadata=self.auth.get_auth_metadata())
#
# File /opt/conda/lib/python3.8/site-packages/grpc/_channel.py:1030, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1021 def __call__(self,
#    1022              request: Any,
#    1023              timeout: Optional[float] = None,
#    (...)
#    1026              wait_for_ready: Optional[bool] = None,
#    1027              compression: Optional[grpc.Compression] = None) -> Any:
#    1028     state, call, = self._blocking(request, timeout, metadata, credentials,
#    1029                                   wait_for_ready, compression)
# -> 1030     return _end_unary_response_blocking(state, call, False, None)
#
# File /opt/conda/lib/python3.8/site-packages/grpc/_channel.py:910, in _end_unary_response_blocking(state, call, with_call, deadline)
#     908         return state.response
#     909 else:
# --> 910     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.INVALID_ARGUMENT
# 	details = "Model is not available on server: Voice English-US for language en-US not found. Please specify the voice name in your SynthesizeSpeechRequest."
# 	debug_error_string = "UNKNOWN:Error received from peer  {created_time:"2025-07-17T12:27:50.228058284+00:00", grpc_status:3, grpc_message:"Model is not available on server: Voice English-US for language en-US not found. Please specify the voice name in your SynthesizeSpeechRequest."}"
# >

# %% [markdown]
# We have all the pieces, and have tested them individually.  Now let's run it as one pipeline.

# %%
# Put it all together

SAMPLE="/dli_workspace/data/audio_sample_resampled2.wav"
print("First Audio sample:")
ipd.display(ipd.Audio(SAMPLE, rate=sample_rate_hz, autoplay=True))

# get input audio duration
d=librosa.get_duration(filename=SAMPLE)
# call Riva ASR  
transcript = asr_predict(SAMPLE)
# call Riva NER
tokens,slots = ner_predict(transcript)
# call Dialog Manager
dm_response = dm_predict(slots, tokens)
# call Riva TTS
synth_audio, processed_text = tts_predict(dm_response)

time.sleep(d)
print("Virtual Assistant Response:")
ipd.display(ipd.Audio(synth_audio, rate=sample_rate_hz, autoplay=True))

# %% [markdown]
# ---
# # 8.2 ASR Customization
#
# Imagine an application with the same basic pipeline that receives restaurant orders.  It may be the case that the standard ASR model does not recognize a particular dish available on the restaurant menu, so recognition of that dish needs to be added to the dictionary.  For our example, let's say that "couscous" has been ordered.

# %%
SAMPLE="/dli_workspace/data/couscous-left.wav"
sample_rate_hz = 44100
ipd.display(ipd.Audio(SAMPLE, rate=sample_rate_hz, autoplay=True))

# get inut audio duration
d=librosa.get_duration(filename=SAMPLE)
# call Riva ASR  
transcript=asr_predict(SAMPLE)
print(transcript)

# %% [markdown]
# The spoken word, "couscous", is not correctly transcribed by the ASR.  Instead, it thinks the spelling is "Css".  Is that because it doesn't know the word, or because it just didn't recognize it?  We can check by searching for the correct spelling in the Conformer-CTC model lexicon.

# %%
import os
CONFORMER_OFFLINE = "conformer-en-US-asr-offline-ctc-decoder-cpu-streaming-offline"
LEXICON = os.path.join(RIVA_MODEL_REPO, "models", CONFORMER_OFFLINE, "1", "lexicon.txt")

! grep couscous $LEXICON

# %% [markdown]
# The word "couscous" is already part of the Riva ASR vocabulary, but was not recognized as the likely transcription. Since this is a restaurant context, we want to improve the likelihood that "couscous" is transcribed, which we can do with word boosting.
#
# _Note: If we have a large list of words of interest like this, we could fine-tune the language model, which would make word boosting unnecessary._

# %% [markdown]
# ## 8.2.1 Word Boosting
#
# Word boosting is the easiest customization of Riva ASR. The boosting  happens at the client side, when querying for transcription. The user can specify a list of words of interest that are most likely to appear and giving them new (higher) scores. The user-specified scores are used for decoding the output of the acoustic model.
#
# In order to boost the word "couscous", we can use the config [`riva.client.add_word_boosting_to_config()`](https://github.com/nvidia-riva/python-clients/blob/928c63273176a939500e01ce176c463f1606a1ff/riva_api/asr.py#L78) function to specify the list of words and their scores.

# %%
# predict with word boosting
def asr_predict_WB(SAMPLE, boost, score):
    auth = riva.client.Auth(uri='localhost:50051')
    riva_asr = riva.client.ASRService(auth)
    # This example uses a .wav file with LINEAR_PCM encoding.
    # read in an audio file from local disk
    # Set up an offline/batch recognition request
    config = riva.client.RecognitionConfig()
    config.language_code = "en-US"                    # Language code of the audio clip
    config.max_alternatives = 1                       # How many top-N hypotheses to return
    config.enable_automatic_punctuation = True        # Add punctuation when end of VAD detected
    config.audio_channel_count = 1     
    riva.client.add_word_boosting_to_config(config, [boost], score)    # ****** WORD BOOSTING ******
    with io.open(SAMPLE, 'rb') as fh:
        content = fh.read()
    response = riva_asr.offline_recognize(content, config)
    transcript=response.results[0].alternatives[0].transcript
    return transcript

# %%
SAMPLE="/dli_workspace/data/couscous-left.wav"
ipd.display(ipd.Audio(SAMPLE, rate=sample_rate_hz, autoplay=True))

# transcibe while boosting couscous with the score 4.0
transcript=asr_predict_WB(SAMPLE,"couscous", 4.0)
print(transcript)

# %% [markdown]
# ## 8.2.2 Exercise: Negative Word Boost
#
# It's also possible to boost with negative numbers to reduce the likelihood of a particular transcription.  Try a few boost numbers, both negative and positive, to see what value is required to get the correct transcription of "couscous".

# %%
# transcibe while boosting couscous with various `myscore` values such as:  -4.0, 1.0, 2.0, 3.0
myscore = -4.0

SAMPLE="/dli_workspace/data/couscous-left.wav"
transcript=asr_predict_WB(SAMPLE,"couscous", myscore)
print(transcript)

# %% [markdown]
# ## 8.2.3 Lexicon Customization
#
# The lexicon is a raw text file that contains the mapping of each word on the vocabulary to its tokenized format (separated by a tab). Tokens must be part of the acoustic model's vocabulary .  <br> For example:
#
# ```
# as      ▁as
# with    ▁with
# not     ▁not
# don't   ▁don ' t
# ```
#
# Customizing the lexicon file creates explicit pronunciations of terms, in the form of tokenized sequences.
# Let's see this in action with the word `bruschetta` that could be pronounced `brusketa`.

# %%
# load sample audio

SAMPLE="/dli_workspace/data/bruschetta_resampled.wav"
ipd.display(ipd.Audio(SAMPLE, rate=sample_rate_hz, autoplay=True))

# call Riva ASR  
transcript=asr_predict(SAMPLE)
print(transcript)

# %% [markdown]
# The transcription is "Bruce Keta", which is not accurate. Let's check if "bruschetta" is part of the vocabulary.

# %%
! grep bruschetta $LEXICON

# %% [markdown]
# The word "bruschetta" is in the lexicon, but it was not recognized by Riva ASR pipeline. The only pronunciation configured is `▁b ru s ch e t t a`.
#
# Let's provide more sequences to recognize the word when pronouncing it "bruce keta".
#
# We'll need to stop the Riva server, customize the pronunciation, and then restart with the update.

# %%
# Stop the Riva server. 
# !bash $RIVA_QS/riva_stop.sh

# %% [markdown]
# Let's locate and load the tokenizer and test the sequence of tokens for the sentence "Hi, my name is Dana".

# %%
import glob
import sentencepiece as spm

# locate the _tokenizer.model in Riva models repo
mydir = os.path.join(RIVA_MODEL_REPO, "models", CONFORMER_OFFLINE, "1")
os.chdir(mydir)
for file in glob.glob("*.model"):
    filename = file
    
tokenizer = os.path.join(RIVA_MODEL_REPO, "models", CONFORMER_OFFLINE, "1", filename)

# Load the tokenizer
s = spm.SentencePieceProcessor(model_file=tokenizer)

# tokenize the sentence
s.encode("Hi, my name is Dana",out_type=str)

# %% [markdown]
# To generate new lexicon possibilities for "bruschetta" using the `encode()` function. We need:
# - PRONUNCIATION: What the word or phrase should sound like (our example: "bruce keta")
# - TOKEN: The desired written form of the word (our example: "bruschetta")
#
# Let's query for five variants of the sequence of tokens leading to this sound.

# %%
TOKEN="bruschetta"
PRONUNCIATION="bruce keta"

for n in range(5):
    print(TOKEN + '\t' + ' '.join(s.encode(PRONUNCIATION, out_type=str, enable_sampling=True, alpha=0.1, nbest_size=-1)))

# %% [markdown]
# Add those pronunciation options to the Riva offline lexicon file.

# %%
# !echo -e "bruschetta\t▁b ru ce ▁k e t a" >> $LEXICON
# !echo -e "bruschetta\t▁b ru c e ▁ k e t a" >> $LEXICON
# !echo -e "bruschetta\t▁b r u c e ▁k e t a" >> $LEXICON
# !echo -e "bruschetta\t▁ b ru c e ▁k e t a" >> $LEXICON
# !echo -e "bruschetta\t▁ b ru ce ▁ k e t a" >> $LEXICON

# %%
# Check that Riva lexicon is updated
! grep bruschetta $LEXICON

# %%
# Start the Riva server (about 1 minute)
# !cd $RIVA_QS && bash riva_start.sh config.sh

# %% [markdown]
# Let's query the customized Riva ASR service again with the updated lexicon.

# %%
SAMPLE = "/dli_workspace/data/bruschetta_resampled.wav"
ipd.display(ipd.Audio(SAMPLE, rate=sample_rate_hz, autoplay=True))

# call Riva ASR  
transcript = asr_predict(SAMPLE)
print("Riva transcription After Lexicon Mapping:\n", transcript)

# %% [markdown]
# ---
# # 8.3 Dialog Manager
#
# Let's suppose we want to make an application that responds to restauran orders.  We could use an NER model trained to recognize restaurant menu items, times, names, and so on.  However, that would mean we would need to fine-tune a model from some relevant dataset and load it into our pipeline.  It's going to be easier to solve this by simply querying a large language model (LLM) that already has the knowledge base we need.
#
# For this purpose, we are going to use LangChain integrations to call an LLM model for chat completion.  The LLM model we'll use is embedded in a [NIM (NVIDIA inference microservice)](https://python.langchain.com/v0.2/docs/integrations/chat/nvidia_ai_endpoints/), hosted on NVIDIA in the [NVIDIA API catalog](https://nvidia.github.io/GenerativeAIExamples/latest/api-catalog.html).  As explained in the NIM documentation, we'll use the `langchain-nvidia-ai-endpoints` library, which has already been installed in the course instance.
#
# Specifically, we'll use the [Llama3-70b model](https://build.nvidia.com/meta/llama3-70b?snippet_tab=Docker), which powers complex conversations with superior contextual understanding, reasoning and text generation.

# %% [markdown]
# ## 8.3.1 API Endpoint Keys
# To call the API endpoints, we need an NVIDIA API key. This is different than the NGC API key you've already generated.  You can generate your own `nvapi-` key that includes a limited amount of tokens by following the steps below and setting it to an environment variable, as explained in the [NIM documentation](https://python.langchain.com/v0.2/docs/integrations/chat/nvidia_ai_endpoints/).  However, for this course that won't be necessary.  We'll use a server to provide a special course key so you can have plenty of tokens to experiment with.

# %% [markdown]
# <details>
#   <summary>Instructions for API key generation</summary>
#   1. Create a free account with <a href="https://build.nvidia.com/">NVIDIA</a>.<br>
#   2. Click on your model of choice. Under Input select the Python tab, and click Get API Key. Then click Generate Key.<br>
#   3. Copy and save the generated key as NVIDIA_API_KEY.<br>
# </details>

# %% [markdown]
# ## 8.3.2 Using LangChain With Llama 3

# %% [markdown]
# Details on the many options for working with LLMs is beyond the scope of this course.  For our purposes, we'll use the [Llama3-70b model](https://build.nvidia.com/meta/llama3-70b?snippet_tab=Docker), which powers complex conversations with superior contextual understanding, reasoning and text generation.  The chat endpoint class we'll use is [ChatNVIDIA](https://api.python.langchain.com/en/latest/chat_models/langchain_nvidia_ai_endpoints.chat_models.ChatNVIDIA.html).

# %%
import os
from langchain_nvidia_ai_endpoints import ChatNVIDIA
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain.text_splitter import CharacterTextSplitter

ChatNVIDIA.get_available_models()

# %% [markdown]
# Although we will just use Llama3-70b, you can see that the endpoint supports many more models.
#
# Let's instantiate our `llm` model with a maximum token number of 256.  At this point, we also need to make sure the API key is available.  This would typically be provided as an environment variable, but for this course, we will just set the `base-url` to an internal wrapper server set up for the course, which will provide the course API key to the endpoint directly.

# %%
llm = ChatNVIDIA(model="meta/llama3-70b-instruct", 
                 max_tokens=256, 
                 base_url=os.getenv('NVIDIA_BASE_URL'))

# %% [markdown]
# We'll create a chain-building function to handle queries to our LLM called `define_chain`.  We'll include the LLM model and an optional prompt as inputs  The output is the text response from the LLM.

# %%
def define_chain(llm, system_prompt = ""):
    prompt = ChatPromptTemplate.from_messages(
                                            [
                                                (
                                                    "system",
                                                    system_prompt,
                                                ),
                                                ("user", "{question}"),
                                            ]
                                           )
    return ({"question": RunnablePassthrough()} | prompt | llm | StrOutputParser())

# %%
chain = define_chain(llm)

# %% [markdown]
# Let's first try this without a prompt.

# %%
request_bruschetta = "I would like to order a bruschetta for 6pm"
dm_response_bruschetta = chain.invoke(request_bruschetta)
print(dm_response_bruschetta)

# %% [markdown]
# ## 8.3.3 Restaurant Menu Prompt
# The result without a prompt did not provide the dialog we want.  We want the LLM to respond as a restaurant would, so we need to tell it the behavior we want and give it a menu to work with.
#
# Let's write a prompt such that the model acts like the restaurant agent. The input will be a food-related query.  Of course we could expand upon the menu if we wanted to, but for this example we'll just focus on bruschetta and pasta.

# %%
restaurant_prompt = "You are a food ordering platform.  \
     Your menu consists of 3 bruschetta options: \
     Tomato and Olive Oil, Mozarella and Basil, Cherry Tomato and Garlic \
     and 3 pasta options: \
     Spaghetti Marinara, Fettuccine Alfredo, Linguini and Clams. \
     A customer can ask yyou your menu options on bruschetta or pasta. \
     Make your answers clear and concise."
chain = define_chain(llm, restaurant_prompt)

# %% [markdown]
# Let's now try a couple of user queries!

# %%
request_bruschetta = "I would like to order a bruschetta for 6pm"
dm_response_bruschetta = chain.invoke(request_bruschetta)
print(dm_response_bruschetta)

# %%
request_pasta = "Can you recommend a good Italian pasta?"
dm_response_pasta = chain.invoke(request_pasta)
print(dm_response_pasta)

# %% [markdown]
# ## 8.3.4 Exercise: Changing the Prompt

# %% [markdown]
# You can play with the prompt as you like, by modifying the `system_prompt` input to the `define_chain` function, and then invoking it. Try it below with a new "rhyming" prompt.  To reveal the solution, click on the elipses ("...").

# %%
restaurant_rhyme_prompt = "You are a food ordering platform.  \
     Your menu consists of 3 bruschetta options: \
     Tomato and Olive Oil, Mozarella and Basil, Cherry Tomato and Garlic \
     and 3 pasta options: \
     Spaghetti Marinara, Fettuccine Alfredo, Linguini and Clams. \
     A customer can ask you your menu options on bruschetta or pasta. \
     Reply in rhyme."

# Set up your chain using the new prompt, then get and print the response generated
# Your code here

# %%
restaurant_rhyme_prompt = "You are a food ordering platform.  \
     Your menu consists of 3 bruschetta options: \
     Tomato and Olive Oil, Mozarella and Basil, Cherry Tomato and Garlic \
     and 3 pasta options: \
     Spaghetti Marinara, Fettuccine Alfredo, Linguini and Clams. \
     A customer can ask you your menu options on bruschetta or pasta. \
     Reply in rhyme."

chain = define_chain(llm, restaurant_rhyme_prompt)

response = chain.invoke(request_pasta)
print(response)

# %% [markdown]
# ---
# # 8.4 TTS Customization
# The correct pronunciation for "bruschetta" may be up for debate depending on where in the world you are.  For our application, we need to settle on a consistent pronunciation, so assume we want that "bruce keta" type of pronunciation we focused on earlier. Without any customization, the TTS model does not pronounce it that way.

# %%
# Generate speech with the OOTB TTS model
dm_response = dm_response_bruschetta
synth_audio, processed_text = tts_predict(dm_response)
ipd.display(ipd.Audio(synth_audio, rate=sample_rate_hz, autoplay=True))

# %% [markdown]
# We can try different pronunciations with the NeMo aligner model as follows:

# %%
from nemo.collections.tts.models import AlignerModel
aligner = AlignerModel.from_pretrained("tts_en_radtts_aligner_ipa")

# %%
input_string = "broo sketah"
text_g2p = aligner.tokenizer.g2p(input_string)
print(text_g2p)
text_tokens = aligner.tokenizer(input_string)
print(text_tokens)
print("\n" + ''.join(text_g2p))
synth_audio, processed_text =tts_predict(''.join(text_g2p))
ipd.display(ipd.Audio(synth_audio, rate=sample_rate_hz, autoplay=True))

# %%
input_string = "brous KETA"
text_g2p = aligner.tokenizer.g2p(input_string)
print(text_g2p)
text_tokens = aligner.tokenizer(input_string)
print(text_tokens)
print("\n" + ''.join(text_g2p))
synth_audio, processed_text =tts_predict(''.join(text_g2p))
ipd.display(ipd.Audio(synth_audio, rate=sample_rate_hz, autoplay=True))

# %% [markdown]
# After trying a few, alter the input to the TTS model with a simple `replace()` in the string output from the DM.

# %%
# generate speech 
custom_dm_response = dm_response.replace("bruschetta", "BROO SKETAH") 

synth_audio, processed_text =tts_predict(custom_dm_response)
ipd.display(ipd.Audio(synth_audio, rate=sample_rate_hz, autoplay=True))

# %% [markdown]
# ---
# # 8.5 Customized Restaurant Pipeline Demo
#
# We've customized several parts of our pipeline:
# 1. ASR - added detection of additional pronunciations with the lexicon
# 3. DM - using the LLM chain we designed
# 4. TTS - added pronunciation substitution
#
#
# <img src="images/pipeline/restaurant_pipeline.png">

# %% [markdown]
# ## 8.5.1 Exercise: Run a Custom Pipeline
#
# In the following cell, complete the "TODO" sections to run the full pipeline with customizations:
# 1. ASR customized lexicon for "bruschetta" (this should already be in place)
# 3. DM with the LLM chain we defined
# 4. TTS with substituted pronunciation for "bruschetta"
#
# (_Hint: Since it's a pipeline, be sure to use the output from each step as the input for the next_)
#
# If you get stuck, you can check the [solution](solutions/ex8.5.1.ipynb)

# %%
# Restaurant Pipeline
# Put it all together

SAMPLE="/dli_workspace/data/bruschetta_resampled.wav"
print("First Audio sample:")
ipd.display(ipd.Audio(SAMPLE, rate=sample_rate_hz, autoplay=True))

# get input audio duration
d=librosa.get_duration(filename=SAMPLE)

# TODO call Riva ASR  
# TODO call LLM Dialog Manager
# TODO call Riva TTS

time.sleep(d)
print("Virtual Assistant Response:")
ipd.display(ipd.Audio(synth_audio, rate=sample_rate_hz, autoplay=True))

# %% [markdown]
# ## 8.5.2 Shut Down Riva

# %%
# Stop the Riva server 
# !bash $RIVA_QS/riva_stop.sh

# %% [markdown]
# ---
# # 8.6 Shut Down the Kernel
# <h3 style="color:red;">Important!</h3>
#
# From the menu above, choose ***Kernel->Shut Down Kernel*** to fully clear GPU memory before moving on.

# %% [markdown]
# ---
# <h2 style="color:green;">Congratulations!</h2>
#
# In this notebook, you have:
# - Built a full conversational AI pipeline
# - Customized ASR and TTS in a full pipeline
# - Added an LLM API endpoint as a Dialog Manager for NLP
# - Built a full restaurant agent customized pipeline
#
# This concludes the TTS portion of the course.<br>
# Next, you'll work with deployment of Riva at scale using Kubernetes, starting with [Enabling GPU within Kubernetes](009_K8s_Enable.ipynb).

# %% [markdown]
# <a href="https://www.nvidia.com/dli"> <img src="images/DLI_Header.png" alt="Header" style="width: 400px;"/> </a>
